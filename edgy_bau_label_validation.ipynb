# %% [markdown]
# # Edgy BAU Label Validation
#
# This notebook validates the CashConnectedGraphChangeEvent generation for BAU (live) LabelEvent processing through the Edgy service by comparing the events generated against expected events computed from Duplograph's graph state.
#
# ## Overview
#
# The validation process:
# 1. Takes a list of label events as input containing:
#    - Source account (CASH_CUSTOMER) token
#    - Label type
#    - Present value of the label (true or false)
#    - Label effective timestamp
# 2. For each label event:
#    - Finds the source account holder
#    - Queries their active (non-merged) accounts
#    - Queries their active labels before and after the current label event
#    - If the label event represents no change in label state, expect no output events
#    - Finds assets connected to the source account holder's accounts
#    - Identifies other account holders connected to the same assets via active (non merged) accounts
#    - Computes expected LabelChange CashConnectedGraphChangeEvents based on shared asset types
#    - Validates generated event IDs against expected events to ensure all expected events are present, and no unexpected events are generated
#    - Validates the connections between source and target in LabelChange.connection_node_types
#    - Validates the timestamp of the events matches the timestamp of the label event
# 3. Performs general sanity checks on the generated events

# %% [markdown]
# ## Setup
#
# First, install required dependencies and import necessary modules.

# %%
# %pip install --extra-index-url https://artifactory.global.square/artifactory/api/pypi/block-pypi/simple sq-pysnowflake==1.6.0
# Out:
# Python interpreter will be restarted.
# Time to validate event C_5jefchmj8/BLACKLISTED/True/1750946683067: 23.08 seconds
# ℹ️ Label Event C_5jefchmj8/BLACKLISTED/True/1750946683067: Source AH AH_8jmhcfej5 has no connected target AHs. No events expected.
#
# Processing input event 3/10: C_g0d4aqmrs/BLACKLISTED/True/1750937263201, effective_at=2025-06-26 11:27:43.201000
# Looking in indexes: https://pypi.org/simple, https://artifactory.global.square/artifactory/api/pypi/block-pypi/simple
# Requirement already satisfied: sq-pysnowflake==1.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (1.6.0)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /databricks/python3/lib/python3.9/site-packages (from sq-pysnowflake==1.6.0) (6.0)
# Requirement already satisfied: tenacity in /databricks/python3/lib/python3.9/site-packages (from sq-pysnowflake==1.6.0) (8.0.1)
# Requirement already satisfied: numpy<2.0,>=1.26 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from sq-pysnowflake==1.6.0) (1.26.4)
# Requirement already satisfied: block-cloud-auth<0.8.0,>=0.7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from sq-pysnowflake==1.6.0) (0.7.19)
# Requirement already satisfied: snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2 in /databricks/python3/lib/python3.9/site-packages (from sq-pysnowflake==1.6.0) (3.15.0)
# Requirement already satisfied: cryptography>41 in /databricks/python3/lib/python3.9/site-packages (from block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (45.0.4)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /databricks/python3/lib/python3.9/site-packages (from block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in /databricks/python3/lib/python3.9/site-packages (from block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (8.0.4)
# Requirement already satisfied: google-auth>=2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (2.40.3)
# Requirement already satisfied: boto3<2.0.0,>=1.34.100 in /databricks/python3/lib/python3.9/site-packages (from block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (1.39.0)
# Requirement already satisfied: google-cloud-compute<2.0.0,>=1.15.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (1.31.0)
# Requirement already satisfied: importlib-resources<7.0.0,>=6.1.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (6.5.2)
# Requirement already satisfied: werkzeug==3.0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (3.0.3)
# Requirement already satisfied: google-cloud-secret-manager>=2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (2.24.0)
# Requirement already satisfied: keyring>=23.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (25.6.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from werkzeug==3.0.3->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (3.0.2)
# Requirement already satisfied: botocore<1.40.0,>=1.39.0 in /databricks/python3/lib/python3.9/site-packages (from boto3<2.0.0,>=1.34.100->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (1.39.0)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /databricks/python3/lib/python3.9/site-packages (from boto3<2.0.0,>=1.34.100->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (0.13.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /databricks/python3/lib/python3.9/site-packages (from boto3<2.0.0,>=1.34.100->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /databricks/python3/lib/python3.9/site-packages (from botocore<1.40.0,>=1.39.0->boto3<2.0.0,>=1.34.100->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /databricks/python3/lib/python3.9/site-packages (from botocore<1.40.0,>=1.39.0->boto3<2.0.0,>=1.34.100->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (1.26.9)
# Requirement already satisfied: cffi>=1.14 in /databricks/python3/lib/python3.9/site-packages (from cryptography>41->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (1.15.0)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.9/site-packages (from cffi>=1.14->cryptography>41->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (2.21)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from google-auth>=2.0.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.9/site-packages (from google-auth>=2.0.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.9/site-packages (from google-auth>=2.0.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (0.2.8)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from google-cloud-compute<2.0.0,>=1.15.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (6.31.1)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from google-cloud-compute<2.0.0,>=1.15.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (2.25.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from google-cloud-compute<2.0.0,>=1.15.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-compute<2.0.0,>=1.15.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-compute<2.0.0,>=1.15.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-compute<2.0.0,>=1.15.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (1.73.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from google-cloud-secret-manager>=2.0.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (0.14.2)
# Requirement already satisfied: zipp>=3.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from importlib-resources<7.0.0,>=6.1.1->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (3.23.0)
# Requirement already satisfied: jaraco.classes in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from keyring>=23.5.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (3.4.0)
# Requirement already satisfied: importlib_metadata>=4.11.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from keyring>=23.5.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (8.7.0)
# Requirement already satisfied: SecretStorage>=3.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from keyring>=23.5.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (3.3.3)
# Requirement already satisfied: jaraco.context in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from keyring>=23.5.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (6.0.1)
# Requirement already satisfied: jeepney>=0.4.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from keyring>=23.5.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (0.9.0)
# Requirement already satisfied: jaraco.functools in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from keyring>=23.5.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (4.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.0.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (0.4.8)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.40.0,>=1.39.0->boto3<2.0.0,>=1.34.100->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests<3.0.0,>=2.20.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests<3.0.0,>=2.20.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from requests<3.0.0,>=2.20.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (2021.10.8)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /databricks/python3/lib/python3.9/site-packages (from snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (2.4.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /databricks/python3/lib/python3.9/site-packages (from snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (1.5.1)
# Requirement already satisfied: pyjwt<3.0.0 in /databricks/python3/lib/python3.9/site-packages (from snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (2.6.0)
# Requirement already satisfied: typing_extensions<5,>=4.3 in /databricks/python3/lib/python3.9/site-packages (from snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (4.14.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /usr/local/lib/python3.9/dist-packages (from snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (2.6.2)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.9/site-packages (from snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (24.2)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=22.0.0 in /databricks/python3/lib/python3.9/site-packages (from snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (25.1.0)
# Requirement already satisfied: tomlkit in /databricks/python3/lib/python3.9/site-packages (from snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (0.13.3)
# Requirement already satisfied: pytz in /databricks/python3/lib/python3.9/site-packages (from snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (2021.3)
# Requirement already satisfied: filelock<4,>=3.5 in /databricks/python3/lib/python3.9/site-packages (from snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (3.6.0)
# Requirement already satisfied: pandas<3.0.0,>=2.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (2.3.0)
# Requirement already satisfied: pyarrow<19.0.0 in /databricks/python3/lib/python3.9/site-packages (from snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (7.0.0)
# Requirement already satisfied: tzdata>=2022.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from pandas<3.0.0,>=2.1.2->snowflake-connector-python[pandas,secure-local-storage]<4.0,>=3.2->sq-pysnowflake==1.6.0) (2025.2)
# Requirement already satisfied: more-itertools in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from jaraco.classes->keyring>=23.5.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (10.7.0)
# Requirement already satisfied: backports.tarfile in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d50fd47f-ddbb-4c1a-9ec3-6214e22c20b4/lib/python3.9/site-packages (from jaraco.context->keyring>=23.5.0->block-cloud-auth<0.8.0,>=0.7.0->sq-pysnowflake==1.6.0) (1.2.0)
# Time to validate event C_s6eaaams6/BLACKLISTED/True/1750945651685: 29.98 seconds
# ℹ️ Label Event C_s6eaaams6/BLACKLISTED/True/1750945651685: Source AH AH_6smaaae6s has no *active* connected target AHs. No events expected.
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 39.56 seconds
# - Fastest validation: 13.93 seconds
# - Slowest validation: 75.90 seconds
# - Total validation time for this batch: 395.62 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_015044.csv
# Validating 10 unique input label events.
# - C_5acvdqm99 -> HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE=True @ 1750947053000
# - C_5mdx2gyf7 -> HAS_CASH_CHECK_RETURNS=False @ 1750948888446
# - C_njcnbayjk -> HAS_CASH_CHECK_RETURNS=False @ 1750948945150
# - C_g925w8yp1 -> HAS_CASH_CARD_DISPUTE=True @ 1750943069000
# - C_sjca2ay78 -> BLACKLISTED=True @ 1750947732800
# - C_njdmwgmy4 -> BLACKLISTED=True @ 1750942173205
# - C_f4eqcamt8 -> BLACKLISTED=True @ 1750934489907
# - C_g4dxwqm3m -> HAS_EV_SUSPENSION=True @ 1750946273310
# - C_ghdpw1myg -> HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE=True @ 1750945416000
# - C_f4cy91mbt -> BLACKLISTED=True @ 1750931245045
#
# Processing input event 1/10: C_5acvdqm99/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750947053000, effective_at=2025-06-26 14:10:53
# Python interpreter will be restarted.

# %%
import pandas as pd
import numpy as np
import csv
import fcntl
import json
import os
import time
import math
from datetime import datetime, timedelta
from typing import List, Set, Dict, Tuple, Optional
from concurrent.futures import ThreadPoolExecutor
import concurrent.futures
from pyspark.sql.functions import col
from pysnowflake import Session
from IPython.display import display, HTML

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# ### Query helpers

# %%
# Define a consistent datetime format for all Snowflake SQL queries
SNOWFLAKE_DT_FORMAT = '%Y-%m-%d %H:%M:%S.%f'

warehouse_2xl = 'etl__2xlarge'
warehouse_large = 'etl__large'
warehouse_medium = 'etl__medium'

def snowflake_query(query: str) -> pd.DataFrame:
    """Execute a query in Snowflake and return results as a pandas DataFrame."""
    with Session(query_tag="ioanna", connection_override_args={'warehouse': warehouse_large}) as sess:
        cursor = sess.execute(query)
        return cursor.fetch_pandas_all()

def spark_query(query: str) -> pd.DataFrame:
    """Execute a query in Spark and return results as a pandas DataFrame."""
    return spark.sql(query).toPandas()
        
def to_sql_list(inputs):
    """Convert a set/list of values to SQL IN clause format"""
    if not inputs:
        return "()"
    return "('" + "','".join(str(x) for x in inputs) + "')"

# %% [markdown]
# ### Validation Result Class
# Tracks validation outcomes and error details for each input label event

# %%
class ValidationResult:
    def __init__(self, label_event_id: str): 
        self.label_event_id = label_event_id 
        self.validation_status: Optional[str] = None
        self.missing_events: Set[str] = set()
        self.unexpected_events: Set[str] = set()
        self.timestamp_errors: List[str] = []
        self.connection_type_errors: List[str] = []
        self.payload_errors: List[str] = []
        self.success: bool = True
        
    def add_error(self, error_type: str, details: str):
        """Records an error of the specified type with details"""
        self.success = False
        if error_type == "validation_status":
            self.validation_status = details
        elif error_type == "missing_event":
            self.missing_events.add(details)
        elif error_type == "unexpected_event":
            self.unexpected_events.add(details)
        elif error_type == "timestamp":
            self.timestamp_errors.append(details)
        elif error_type == "connection_type":
            self.connection_type_errors.append(details)
        elif error_type == "payload_error":
            self.payload_errors.append(details)
            
    def get_summary(self) -> str:
        """Generates a human-readable summary of validation results"""
        summary = []
        
        identifier = self.label_event_id

        if self.validation_status:
            summary.append(f"ℹ️ Label Event {identifier}: {self.validation_status}")
        elif self.success:
            summary.append(f"✅ Label Event {identifier}: All validations passed")
        else:
            summary.append(f"❌ Label Event {identifier}: Validation failed")
        
        if self.missing_events:
            summary.append(f"\nMissing events ({len(self.missing_events)}):")
            for event in sorted(self.missing_events):
                summary.append(f"  - {event}")
        if self.unexpected_events:
            summary.append(f"\nUnexpected events ({len(self.unexpected_events)}):")
            for event in sorted(self.unexpected_events):
                summary.append(f"  - {event}")
        if self.timestamp_errors:
            summary.append(f"\nTimestamp errors ({len(self.timestamp_errors)}):")
            for error in self.timestamp_errors:
                summary.append(f"  - {error}")
        if self.connection_type_errors:
            summary.append(f"\nConnection Type errors ({len(self.connection_type_errors)}):")
            for error in self.connection_type_errors:
                summary.append(f"  - {error}")
        if self.payload_errors:
            summary.append(f"\nPayload errors ({len(self.payload_errors)}):")
            for error in self.payload_errors:
                summary.append(f"  - {error}")
        return "\n".join(summary)

    def write_to_csv(self, csv_path: str):
        """Writes this validation result to CSV in a thread-safe manner.
        
        Args:
            csv_path: Path to the CSV file
        """
        row_data = {
            'label_event_id': self.label_event_id,
            'validation_success': self.success,
            'validation_status': self.validation_status if self.validation_status else \
                               ('PASS' if self.success else 'FAIL'),
            'missing_events': '|'.join(sorted(self.missing_events)) if self.missing_events else '',
            'unexpected_events': '|'.join(sorted(self.unexpected_events)) if self.unexpected_events else '',
            'timestamp_errors': '|'.join(self.timestamp_errors) if self.timestamp_errors else '',
            'connection_type_errors': '|'.join(self.connection_type_errors) if self.connection_type_errors else '',
            'payload_errors': '|'.join(self.payload_errors) if self.payload_errors else ''
        }
        
        fieldnames = [
            'label_event_id',
            'validation_success',
            'validation_status',
            'missing_events',
            'unexpected_events',
            'timestamp_errors',
            'connection_type_errors',
            'payload_errors'
        ]
        
        file_exists = os.path.exists(csv_path)
        
        with open(csv_path, 'a' if file_exists else 'w', newline='') as f:
            fcntl.flock(f.fileno(), fcntl.LOCK_EX)
            try:
                writer = csv.DictWriter(f, fieldnames=fieldnames)
                
                if not file_exists:
                    writer.writeheader()
                
                writer.writerow(row_data)
                
                f.flush()
                os.fsync(f.fileno())
            finally:
                fcntl.flock(f.fileno(), fcntl.LOCK_UN)

# %% [markdown]
# ### Event ID Generation
# Replicates Edgy's LabelChange event ID generation logic for consistency checking.

# %%
def label_event_type_marker(event_type_str: str) -> str:
    """Converts a label event type string to its ID marker."""
    if event_type_str == "LABEL_ADDED":
        return "+"
    elif event_type_str == "LABEL_REMOVED":
        return "-"
    else:
        raise ValueError(f"Unsupported label event type for ID generation: {event_type_str}")

def label_change_event_id(
    target_token: str, 
    source_token: str, 
    label_type_name: str, # e.g., "SUSPICIOUS_ACTIVITY"
    effective_at_millis: int, 
    event_type_str: str # e.g., "LABEL_ADDED" or "LABEL_REMOVED"
) -> str:
    """
    Produces a LabelChange event_id in the same format as edgy.
    Format: L/<targetUserToken>/<sourceUserToken>/<labelTypeName>/<effectiveAtMillis>/{+,-}
    Note: Tokens are NOT alphabetically sorted for LabelChange event IDs.
    """
    marker = label_event_type_marker(event_type_str)
    return f"L/{target_token}/{source_token}/{label_type_name}/{effective_at_millis}/{marker}"

# %% [markdown]
# ### Timestamp validation
#
# Validation of change event timestamps

# %%
def validate_timestamps(
    actual_events_df: pd.DataFrame, 
    expected_effective_at_millis: int, 
    validation_result: ValidationResult
) -> None:
    """
    Validates that all actual LabelChange events have the expected effective_at_millis.
    Assumes actual_events_df is not empty and contains required columns if called.

    Args:
        actual_events_df: DataFrame of actual LabelChange CashConnectedGraphChangeEvents.
                          Expected columns: ['event_id', 'effective_at_millis'].
        expected_effective_at_millis: The expected effective_at_millis for these events,
                                      derived from the input label event.
        validation_result: ValidationResult object to store any errors.
    """

    # Find rows with mismatched timestamps
    mismatched_df = actual_events_df[
        actual_events_df['effective_at_millis'] != expected_effective_at_millis
    ]

    if not mismatched_df.empty:
        expected_dt_str = pd.to_datetime(expected_effective_at_millis, unit='ms').strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
        
        for _, event_row in mismatched_df.iterrows():
            actual_event_timestamp_millis = event_row['effective_at_millis']
            actual_dt_str = pd.to_datetime(actual_event_timestamp_millis, unit='ms').strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
            
            validation_result.add_error(
                "timestamp",
                f"Timestamp mismatch for event {event_row['event_id']}:\n"
                f"  Expected (from input label event): {expected_dt_str} ({expected_effective_at_millis} ms)\n"
                f"  Actual (in generated event): {actual_dt_str} ({actual_event_timestamp_millis} ms)"
            )

# %% [markdown]
# ### Label Retrieval and Impact Assessment
# Functions to retrieve active labels and determine the impact of a label event on the account holder's active labels

# %%
def get_account_holder_labels(
    account_holder_accounts: Dict[str, Set[str]],
    effective_at: str
) -> pd.DataFrame:
    """Gets active labels for account holders via their accounts.
    
    Args:
        account_holder_accounts: Dict mapping account holder tokens to their active account tokens
        effective_at: Timestamp for point-in-time query
        
    Returns:
        DataFrame with label information
    """
    # Flatten account tokens for the query
    all_accounts = {
        account 
        for accounts in account_holder_accounts.values() 
        for account in accounts
    }
    
    if not all_accounts:
        return pd.DataFrame(columns=[
            'ACCOUNT_HOLDER_TOKEN', 'ACCOUNT_TOKEN', 'LABEL',
            'LABEL_EFFECTIVE_AT', 'ACCOUNT_MAPPING_EFFECTIVE_AT'
        ])

    query = f"""
    WITH latest_label_events AS (
        SELECT node_token,
               label,
               present,
               effective_at,
               ROW_NUMBER() OVER (PARTITION BY node_token, label ORDER BY effective_at DESC) as rn
        FROM duplograph.public.label_events
        WHERE node_type = 'CASH_CUSTOMER'
        AND effective_at <= '{effective_at}'
        AND node_token IN {to_sql_list(all_accounts)}
    )
    SELECT 
        m.from_token AS ACCOUNT_HOLDER_TOKEN,
        m.to_token AS ACCOUNT_TOKEN,
        l.label AS LABEL,
        l.effective_at AS LABEL_EFFECTIVE_AT,
        m.effective_at AS ACCOUNT_MAPPING_EFFECTIVE_AT
    FROM latest_label_events l
    JOIN duplograph.public.edges m 
        ON l.node_token = m.to_token
    WHERE l.rn = 1 
    AND l.present = true
    AND m.from_type = 'ACCOUNT_HOLDER_CASH_CUSTOMER'
    AND m.to_type = 'CASH_CUSTOMER'
    AND m.effective_at <= '{effective_at}'
    AND m.from_token IN {to_sql_list(account_holder_accounts.keys())}
    ORDER BY 
        m.from_token,
        m.to_token,
        l.label
    """
    
    return snowflake_query(query)

# %%
def get_label_event_impact(
    source_ah_token: str,
    source_ah_accounts: Set[str],
    label_type: str,
    effective_at_str: str # Expects formatted string, matching SNOWFLAKE_DT_FORMAT
) -> str:
    """
    Determines if an input label event results in an effective label addition, removal,
    or no net change to the source account holder's aggregated active labels for that specific label type.

    It compares the set of active labels for the account holder *before* and *at* the
    provided effective_at_str.

    Args:
        source_ah_token: The token of the source account holder.
        source_ah_accounts: A set of active account tokens for the source account holder.
        label_type: The label type from the input label event (e.g., "SUSPICIOUS_ACTIVITY").
        effective_at_str: The effective_at timestamp as a string, formatted according
                          to SNOWFLAKE_DT_FORMAT. This represents the "at" state.
                          The "before" state is calculated by subtracting 1ms.

    Returns:
        A string: "LABEL_ADDED", "LABEL_REMOVED", or "NO_CHANGE".
    """
    # ACCOUNT_DENYLISTED applies only to accounts, it should produce no events for account holders
    if label_type == "ACCOUNT_DENYLISTED":
        return "NO CHANGE"

    event_effective_at_dt = pd.to_datetime(effective_at_str) # Convert to datetime for timedelta

    ah_accounts_map = {source_ah_token: source_ah_accounts}

    # 1. Determine "Before" state
    effective_at_before_dt = event_effective_at_dt - timedelta(milliseconds=1)
    effective_at_before_query_str = effective_at_before_dt.strftime(SNOWFLAKE_DT_FORMAT)
    
    df_before = get_account_holder_labels(
        account_holder_accounts=ah_accounts_map,
        effective_at=effective_at_before_query_str
    )
    active_labels_before = set(df_before['LABEL'].unique()) if not df_before.empty else set()

    # 2. Determine "At" state (using the original effective_at_str)
    df_at = get_account_holder_labels(
        account_holder_accounts=ah_accounts_map,
        effective_at=effective_at_str 
    )
    active_labels_at = set(df_at['LABEL'].unique()) if not df_at.empty else set()
            
    label_active_before = label_type in active_labels_before
    label_active_at = label_type in active_labels_at

    if label_active_at and not label_active_before:
        return "LABEL_ADDED"
    elif not label_active_at and label_active_before: 
        return "LABEL_REMOVED"
    else:
        return "NO_CHANGE"

# %% [markdown]
# ### Account Holder Functions
# Functions to analyze account holders and their connections.

# %%
def get_ah_for_account(
    account_token: str,
    effective_at: str
) -> Optional[str]:
    """Gets the account holder for a CASH_CUSTOMER account.
    
    Args:
        account_token: The CASH_CUSTOMER token to find the account holder for
        effective_at: Timestamp for point-in-time query
        
    Returns:
        The ACCOUNT_HOLDER_CASH_CUSTOMER token or None if not found
    """
    query = f"""
    SELECT FROM_TOKEN as ACCOUNT_HOLDER_TOKEN
    FROM duplograph.public.edges
    WHERE FROM_TYPE = 'ACCOUNT_HOLDER_CASH_CUSTOMER'
    AND TO_TYPE = 'CASH_CUSTOMER'
    AND TO_TOKEN = '{account_token}'
    AND EFFECTIVE_AT <= '{effective_at}'
    """
    
    df = snowflake_query(query)
    return df['ACCOUNT_HOLDER_TOKEN'].iloc[0] if not df.empty else None

# %%
def get_all_active_accounts(
    account_holders: Set[str],
    effective_at: str
) -> Dict[str, Set[str]]:
    """Gets all active (non-merged) accounts for a set of account holders.
    
    Args:
        account_holders: Set of account holder tokens to get accounts for
        effective_at: Timestamp for point-in-time query
        
    Returns:
        Dictionary mapping account holder tokens to their set of active (non-merged) account tokens.
        Account holders with no active accounts will have empty sets or be missing from the dictionary.
    """
    if not account_holders:
        return {}
        
    query = f"""
    WITH account_edges AS (
        -- Get all account mappings for the account holders
        SELECT 
            FROM_TOKEN AS account_holder_token,
            TO_TOKEN AS account_token,
            EFFECTIVE_AT AS mapping_effective_at
        FROM duplograph.public.edges
        WHERE FROM_TYPE = 'ACCOUNT_HOLDER_CASH_CUSTOMER'
        AND TO_TYPE = 'CASH_CUSTOMER'
        AND FROM_TOKEN IN {to_sql_list(account_holders)}
        AND EFFECTIVE_AT <= '{effective_at}'
    )
    SELECT 
        ae.account_holder_token,
        ae.account_token
    FROM account_edges ae
    WHERE NOT EXISTS (
        -- Exclude merged accounts
        SELECT 1
        FROM duplograph.public.edges m
        WHERE m.FROM_TOKEN = ae.account_token
        AND m.FROM_TYPE = 'CASH_CUSTOMER'
        AND m.TO_TYPE = 'CASH_CUSTOMER'
        AND m.EFFECTIVE_AT <= '{effective_at}'
    )
    """
    
    df = snowflake_query(query)
    
    # Convert to dictionary mapping account holders to their account sets
    result = {}
    if not df.empty:
        for account_holder in account_holders:
            accounts = df[df['ACCOUNT_HOLDER_TOKEN'] == account_holder]['ACCOUNT_TOKEN'].tolist()
            result[account_holder] = set(accounts)
    
    return result

# %%
def get_connected_account_holders(
    source_account_holder: str,
    source_active_accounts: Set[str],
    effective_at: str,
    asset_types: Optional[Set[str]] = None
) -> Tuple[pd.DataFrame, pd.DataFrame, Set[str]]:
    """Gets account holders connected to source accounts via shared assets.
    Note: Returns all connected accounts, including merged ones.
    Merged account filtering should be done by the caller.
    
    Args:
        source_account_holder: The source account holder token
        source_active_accounts: Set of active (non-merged) account tokens belonging to the source account holder
        effective_at: Timestamp for point-in-time query
        asset_types: Optional set of asset types to filter by
        
    Returns:
        Tuple of (
            asset_connections: DataFrame with asset connection details including:
                - ACCOUNT_TOKEN: The connected account
                - ASSET_TOKEN: The shared asset
                - ASSET_TYPE: Type of the shared asset
                - ASSET_CONNECTION_TIME: When the account connected to the asset
                - SOURCE_CONNECTION_TIME: When the source account connected to the asset
                - ACCOUNT_HOLDER_TOKEN: The account holder owning the connected account
                - EARLIEST_CONNECTION_TIME: Later of source and target connection times
            holder_mapping: DataFrame mapping account holders to their connected accounts:
                - ACCOUNT_HOLDER_TOKEN: The account holder
                - ACCOUNT_TOKEN: Their account that shares an asset
                - MAPPING_EFFECTIVE_AT: When the account was mapped to the holder
            connected_holders: Set of account holder tokens that share assets with the source
        )
    """
    if not source_active_accounts:
        return pd.DataFrame(), pd.DataFrame(), set()
        
    asset_type_clause = "1=1"
    if asset_types:
        asset_type_clause = f"TO_TYPE IN {to_sql_list(asset_types)}"
        
    query = f"""
    WITH source_assets AS (
        -- Get assets connected to source accounts
        SELECT DISTINCT 
            TO_TOKEN,
            TO_TYPE,
            MIN(EFFECTIVE_AT) as SOURCE_CONNECTION_TIME  -- When source first connected
        FROM duplograph.public.edges
        WHERE FROM_TYPE = 'CASH_CUSTOMER'
        AND FROM_TOKEN IN {to_sql_list(source_active_accounts)}
        AND TO_TYPE != 'CASH_CUSTOMER'
        AND {asset_type_clause}
        AND EFFECTIVE_AT <= '{effective_at}'
        GROUP BY TO_TOKEN, TO_TYPE
    ),
    connected_accounts AS (
        -- Get accounts connected to those assets, excluding source accounts
        SELECT DISTINCT
            e.FROM_TOKEN AS ACCOUNT_TOKEN,
            e.TO_TOKEN AS ASSET_TOKEN,
            e.TO_TYPE AS ASSET_TYPE,
            MIN(e.EFFECTIVE_AT) AS ASSET_CONNECTION_TIME,  -- When target first connected
            MIN(sa.SOURCE_CONNECTION_TIME) AS SOURCE_CONNECTION_TIME
        FROM duplograph.public.edges e
        JOIN source_assets sa ON e.TO_TOKEN = sa.TO_TOKEN 
            AND e.TO_TYPE = sa.TO_TYPE
        WHERE e.FROM_TYPE = 'CASH_CUSTOMER'
        AND e.FROM_TOKEN NOT IN {to_sql_list(source_active_accounts)}
        AND e.EFFECTIVE_AT <= '{effective_at}'
        GROUP BY e.FROM_TOKEN, e.TO_TOKEN, e.TO_TYPE
    ),
    account_holders AS (
        -- Get account holder relationships for connected accounts
        SELECT 
            e.FROM_TOKEN AS ACCOUNT_HOLDER_TOKEN,
            e.TO_TOKEN AS ACCOUNT_TOKEN,
            e.EFFECTIVE_AT AS MAPPING_EFFECTIVE_AT
        FROM duplograph.public.edges e
        WHERE e.FROM_TYPE = 'ACCOUNT_HOLDER_CASH_CUSTOMER'
        AND e.TO_TYPE = 'CASH_CUSTOMER'
        AND e.TO_TOKEN IN (SELECT ACCOUNT_TOKEN FROM connected_accounts)
        AND e.FROM_TOKEN != '{source_account_holder}'
        AND e.EFFECTIVE_AT <= '{effective_at}'
    ),
    connections AS (
        -- Join with account holders and get earliest connection times
        SELECT 
            ca.*,
            ah.ACCOUNT_HOLDER_TOKEN,
            ah.MAPPING_EFFECTIVE_AT,
            -- For each account holder, find the earliest effective connection time
            -- (the later of source connection and target connection)
            MIN(GREATEST(ca.ASSET_CONNECTION_TIME, ca.SOURCE_CONNECTION_TIME)) 
                OVER (PARTITION BY ah.ACCOUNT_HOLDER_TOKEN, ca.ASSET_TYPE) AS EARLIEST_CONNECTION_TIME
        FROM connected_accounts ca
        JOIN account_holders ah ON ca.ACCOUNT_TOKEN = ah.ACCOUNT_TOKEN
    )
    SELECT * FROM connections
    ORDER BY ACCOUNT_HOLDER_TOKEN, ASSET_TOKEN
    """
    
    df = snowflake_query(query)
    
    if df.empty:
        return df, pd.DataFrame(), set()
        
    # Extract unique account holder tokens
    connected_holders = set(df['ACCOUNT_HOLDER_TOKEN'].unique())
    
    # Create account holder mapping DataFrame
    holder_mapping = df[['ACCOUNT_HOLDER_TOKEN', 'ACCOUNT_TOKEN', 'MAPPING_EFFECTIVE_AT']].drop_duplicates()
    
    # Create asset connections DataFrame
    asset_connections = df[[
        'ACCOUNT_TOKEN', 'ASSET_TOKEN', 'ASSET_TYPE', 'ASSET_CONNECTION_TIME',
        'SOURCE_CONNECTION_TIME', 'ACCOUNT_HOLDER_TOKEN', 'EARLIEST_CONNECTION_TIME'
    ]].drop_duplicates()
    
    return asset_connections, holder_mapping, connected_holders

# %% [markdown]
# ## Main Validation Logic
#
# The core validation function that orchestrates the validation process for each input label event.

# %%
def validate_no_events_condition(
    label_event_id: str, # CHANGED from account_holder
    actual_events: Set[str],
    status_message: str
) -> ValidationResult:
    """Validates cases where no events should be present for a given input label event.
    
    Args:
        label_event_id: The identifier for the input label event being validated.
        actual_events: Set of actual event IDs found for this input.
        status_message: Status message explaining why no events are expected.
        
    Returns:
        ValidationResult: Result object with appropriate status and any unexpected events.
    """
    result = ValidationResult(label_event_id)
    
    if actual_events:
        result.add_error("validation_status", status_message)
        for event_id_val in actual_events: # Renamed event_id to event_id_val to avoid conflict
            result.add_error("unexpected_event", event_id_val)
    else:
        result.success = True
        result.validation_status = status_message
    
    return result

# %%
def get_actual_label_change_events(
    account_token: str,
    label_type: str, 
    present: bool,
    effective_at_ms: int,
    ccgce_table: str
) -> pd.DataFrame:
    """
    Fetches actual LabelChange CashConnectedGraphChangeEvents from the specified table,
    filtered by source account and label type that changed on the source and the
    effective_at time of the label change.

    Args:
        account_token: The source account holder token.
        label_type: The label type expected in event.label_change.changed_source_user_label.
        present: Boolean indicating whether the label was present or not
        effective_at_ms: The effective_at timestamp of the label change in millis
        ccgce_table: The Databricks table containing CashConnectedGraphChangeEvents.

    Returns:
        Pandas DataFrame of matching LabelChange events.
    """
    query = f"""
    SELECT 
        cash_connected_graph_change_event.event_id as event_id,
        cash_connected_graph_change_event.source_user_token as source_user_token,
        cash_connected_graph_change_event.target_user_token as target_user_token,
        cash_connected_graph_change_event.effective_at_millis as effective_at_millis,
        cash_connected_graph_change_event.published_at_millis as published_at_millis,
        cash_connected_graph_change_event.event_type as event_type,
        cash_connected_graph_change_event.label_change.changed_source_user_label as changed_source_user_label,
        cash_connected_graph_change_event.label_change.connection_node_types as connection_node_types
    FROM {ccgce_table}
    WHERE cash_connected_graph_change_event.label_change.source_label_event.node.token = '{account_token}'
    AND cash_connected_graph_change_event.label_change.source_label_event.label = '{label_type}'
    AND cash_connected_graph_change_event.label_change.source_label_event.present = '{present}'
    AND cash_connected_graph_change_event.label_change.source_label_event.effective_at_msec = '{effective_at_ms}'
    """
    actual_events_df = spark_query(query)
    return actual_events_df

# %%
def validate_connection_types(
    actual_events_df: pd.DataFrame, # Contains event_id and actual 'connection_node_types' (list)
    expected_connection_types_map: Dict[str, Set[str]], # Maps event_id to a SET of expected node type strings
    validation_result: ValidationResult
) -> None:
    """
    Validates the connection_node_types in LabelChange events.

    Args:
        actual_events_df: DataFrame of actual LabelChange events to validate.
                          Expected columns: ['event_id', 'connection_node_types'].
        expected_connection_types_map: A dictionary mapping event_id to a SET
                                       of expected connection node type strings.
        validation_result: ValidationResult object to store errors.
    """
    if actual_events_df.empty:
        return

    required_columns = ['event_id', 'connection_node_types']
    if not all(col in actual_events_df.columns for col in required_columns):
        validation_result.add_error(
            "connection_type", # Using the error type we defined in ValidationResult
            f"actual_events_df missing required columns for connection_types validation. Expected: {required_columns}"
        )
        return

    for _, event_row in actual_events_df.iterrows():
        event_id = event_row['event_id']
        actual_types_set = set(event_row['connection_node_types']) # This is a list from the event payload

        expected_types_set = expected_connection_types_map.get(event_id)

        if expected_types_set is None:
            # This case should ideally not happen if actual_events_df is already filtered
            # to include only events for which we have expectations.
            # However, if it does, it means we have an actual event we didn't form expectations for.
            # This might be an "unexpected event" already, or a logic error in preparing expected_connection_types_map.
            # For now, we can log it if it occurs.
            validation_result.add_error(
                "connection_type",
                f"Event {event_id} found in actual_events_df but no expected connection types were prepared for it."
            )
            continue

        if actual_types_set != expected_types_set:
            validation_result.add_error(
                "connection_type",
                f"Connection type mismatch for event {event_id}:\n"
                f"  Expected: {sorted(expected_types_set)}\n"
                f"  Actual:   {sorted(actual_types_set)}"
            )

# %%
def validate_bau_label_event(
    node_token: str,
    label_type: str,
    label_present: bool,
    effective_at_ms: int, 
    ccgce_table: str
) -> ValidationResult:
    """
    Orchestrates the validation process for a single input BAU label event.

    It determines the impact of the label event on the source account holder's
    active labels and compares generated CashConnectedGraphChangeEvents (if any)
    against expected events computed from Duplograph's state.

    Args:
        node_token: The CASH_CUSTOMER token from the input label event.
        label_type: The label type string from the input label event.
        label_present: Boolean indicating if the label is present in the input event.
        effective_at_ms: The effective_at timestamp of the input label event, as epoch milliseconds.
        ccgce_table: The Databricks table containing actual Edgy-generated
                     CashConnectedGraphChangeEvents.

    Returns:
        A ValidationResult object summarizing the outcome for this input label event.
    """
    label_event_id = f"{node_token}/{label_type}/{label_present}/{effective_at_ms}"

    validation_result = ValidationResult(label_event_id)

    effective_at_dt = pd.to_datetime(effective_at_ms, unit='ms')
    effective_at_str = effective_at_dt.strftime(SNOWFLAKE_DT_FORMAT)

    # Fetch LabelChange events that have this LabelEvent as their source event
    actual_events_df = get_actual_label_change_events(
        account_token=node_token,
        label_type=label_type,
        present=label_present,
        effective_at_ms=effective_at_ms,
        ccgce_table=ccgce_table
    )
    actual_event_id_set = set(actual_events_df['event_id'])

    source_ah_token = get_ah_for_account(node_token, effective_at_str)

    if not source_ah_token:
        return validate_no_events_condition(
            label_event_id, actual_event_id_set,
            f"Could not find AH for CASH_CUSTOMER {node_token} at {effective_at_str}."
        )

    source_ah_accounts_map = get_all_active_accounts({source_ah_token}, effective_at_str)
    source_ah_active_accounts = source_ah_accounts_map.get(source_ah_token, set())

    if not source_ah_active_accounts:
        return validate_no_events_condition(
            label_event_id, actual_event_id_set,
            f"Source AH {source_ah_token} has no active accounts. No LabelChange events expected."
        )

    label_impact = get_label_event_impact(
        source_ah_token, source_ah_active_accounts, label_type, effective_at_str
    )

    if label_impact == "NO_CHANGE":
        return validate_no_events_condition(
            label_event_id, actual_event_id_set,
            f"Input label event resulted in NO_CHANGE to AH {source_ah_token}'s active labels for {label_type}. No events expected."
        )
    
    asset_connections_df, _, connected_target_ahs_all = get_connected_account_holders(
        source_ah_token, source_ah_active_accounts, effective_at_str
    )

    if not connected_target_ahs_all:
        return validate_no_events_condition(
            label_event_id, actual_event_id_set,
            f"Source AH {source_ah_token} has no connected target AHs. No events expected."
        )
        
    target_ahs_accounts_map = get_all_active_accounts(connected_target_ahs_all, effective_at_str)
    active_target_ahs = { ah for ah, accs in target_ahs_accounts_map.items() if accs }

    if not active_target_ahs:
        return validate_no_events_condition(
            label_event_id, actual_event_id_set,
            f"Source AH {source_ah_token} has no *active* connected target AHs. No events expected."
        )

    expected_event_ids = set()
    expected_connection_types_map = {} 

    for target_ah_token in active_target_ahs:
        shared_assets_for_this_target_df = asset_connections_df[
            asset_connections_df['ACCOUNT_HOLDER_TOKEN'] == target_ah_token
        ]
        if not shared_assets_for_this_target_df.empty:
            shared_asset_type_names = set(shared_assets_for_this_target_df['ASSET_TYPE'].unique())
            if shared_asset_type_names:
                event_id = label_change_event_id(
                    target_token=target_ah_token, source_token=source_ah_token,
                    label_type_name=label_type, effective_at_millis=effective_at_ms,
                    event_type_str=label_impact 
                )
                expected_event_ids.add(event_id)
                expected_connection_types_map[event_id] = shared_asset_type_names

    if not expected_event_ids: # This means no shared assets with *active* targets generated any expected event_ids
        return validate_no_events_condition(
            label_event_id, actual_event_id_set, # Check against all related actuals
            f"No expected events generated for AH {source_ah_token} (e.g. no shared assets with active targets). No events expected."
        )

    missing = expected_event_ids - actual_event_id_set 
    for eid in missing: validation_result.add_error("missing_event", eid)
    
    # Unexpected events are those in the fetched 'actual_event_id_set'
    # that are not in our 'expected_event_ids'.
    unexpected = actual_event_id_set - expected_event_ids
    for eid in unexpected: validation_result.add_error("unexpected_event", eid)

    events_to_validate_ids = expected_event_ids.intersection(actual_event_id_set)
    
    if events_to_validate_ids:
        events_to_validate_df = actual_events_df[actual_events_df['event_id'].isin(events_to_validate_ids)].copy()

        if not events_to_validate_df.empty:
            mismatched_label_payload_df = events_to_validate_df[
                events_to_validate_df['changed_source_user_label'] != label_type
            ]
            for _, event_row in mismatched_label_payload_df.iterrows():
                validation_result.add_error(
                    "payload_error", 
                    f"Event {event_row['event_id']} has incorrect changed_source_user_label: "
                    f"Expected '{label_type}', Actual '{event_row['changed_source_user_label']}'"
                )
            
            validate_timestamps(
                events_to_validate_df, effective_at_ms, validation_result
            )

            validate_connection_types(
                events_to_validate_df, expected_connection_types_map, validation_result
            )

    if validation_result.success and not validation_result.validation_status:
         validation_result.validation_status = "All validations passed"

    return validation_result

# %%
def validate_label_events(
    label_events_set: Set[Tuple[str, str, bool, int]],
    ccgce_table: str,
    output_dir: Optional[str] = None,
    csv_path: Optional[str] = None
) -> List[ValidationResult]:
    """Validates Edgy BAU label event processing for multiple input label events.
    
    Args:
        label_events_set: Set of Tuples, where each Tuple contains
                               the details of an input label event in the order:
                               (node_token, label_type, present, effective_at_millis)
        ccgce_table: The Databricks table containing CashConnectedGraphChangeEvents.
        output_dir: Optional directory for output files. Defaults to current directory.
        csv_path: Optional explicit path for the output CSV file.
        
    Returns:
        List of ValidationResult objects, one per input label event.
    """
    input_label_events_list = list(label_events_set)
    num_events_to_validate = len(input_label_events_list)
    print(f"Validating {num_events_to_validate} unique input label events.")
    for label_event in label_events_set:
        print(f"- {label_event[0]} -> {label_event[1]}={label_event[2]} @ {label_event[3]}")

    if output_dir:
        os.makedirs(output_dir, exist_ok=True)
    else:
        output_dir = '.'
            
    if csv_path is None:
        timestamp_str = datetime.now().strftime('%Y%m%d_%H%M%S')
        csv_path = os.path.join(output_dir, f'bau_label_validation_{timestamp_str}.csv') 
    
    all_results = []
    timings = {} 
    errors = []
    
    for i, event_tuple in enumerate(input_label_events_list):
        node_token, label_type, present, effective_at_millis = event_tuple
        label_event_id = f"{node_token}/{label_type}/{present}/{effective_at_millis}"
        # For printing, convert millis to datetime string
        effective_at_str = pd.to_datetime(effective_at_millis, unit='ms')
        print(f"\nProcessing input event {i+1}/{num_events_to_validate}: {label_event_id}, effective_at={effective_at_str}")
        
        start_time = time.time()
        
        try:
            result = validate_bau_label_event(
                node_token=node_token,
                label_type=label_type,
                label_present=present,
                effective_at_ms=effective_at_millis, 
                ccgce_table=ccgce_table
            )
            all_results.append(result)
            
            result.write_to_csv(csv_path) 
            
            end_time = time.time()
            duration = end_time - start_time
            timings[label_event_id] = duration
            
            print(f"Time to validate event {label_event_id}: {duration:.2f} seconds")
            print(result.get_summary())
        except Exception as e:
            error_msg = f"ERROR while validating label event {label_event_id}: {type(e).__name__}: {e}"
            print(error_msg)
            errors.append((label_event_id, e))
            # Optionally: Keep running or re-raise depending on workflow; here we keep running next events

    success_count = sum(1 for r in all_results if getattr(r, 'success', False))
    print(f"\nValidation complete: {success_count}/{num_events_to_validate} input label events passed.")
    
    if errors:
        print(f"\n{len(errors)} label events failed due to code errors:")
        for label_id, err in errors:
            print(f"  {label_id}: {type(err).__name__}: {err}")

    if timings:
        avg_time = sum(timings.values()) / len(timings)
        max_time_val = max(timings.values())
        min_time_val = min(timings.values())
        print(f"\nTiming statistics:")
        print(f"- Average time per input label event: {avg_time:.2f} seconds")
        print(f"- Fastest validation: {min_time_val:.2f} seconds")
        print(f"- Slowest validation: {max_time_val:.2f} seconds")
        print(f"- Total validation time for this batch: {sum(timings.values()):.2f} seconds")
    
    print(f"\nResults written to: {csv_path}")
    return all_results

# %%
def validate_label_events_batch(
    label_events_set: Set[Tuple[str, str, bool, int]],
    ccgce_table: str,
    output_dir: str,
    batch_size: int = 5,
    max_workers: int = 3
):
    """Validates input label events in parallel batches.
    
    Args:
        label_events_set: Set of Tuples representing input label events.
                                Each tuple: (node_token, label_type, present, effective_at_millis)
        ccgce_table: The Databricks table for CashConnectedGraphChangeEvents.
        output_dir: Directory for output CSV file.
        batch_size: Number of label events to process in each parallel batch.
        max_workers: Maximum number of parallel threads.
    """
    os.makedirs(output_dir, exist_ok=True)
    
    timestamp_str = datetime.now().strftime('%Y%m%d_%H%M%S')
    csv_path = os.path.join(output_dir, f'bau_label_validation_{timestamp_str}.csv') 
    
    input_label_events_list = list(label_events_set)
    num_total_events = len(input_label_events_list)
    num_batches = math.ceil(num_total_events / batch_size)
    
    batches = [
        set(input_label_events_list[i * batch_size:(i + 1) * batch_size])
        for i in range(num_batches)
    ]
    
    print(f"Processing {num_total_events} unique input label events in {num_batches} batches "
          f"of up to size {batch_size}, using {max_workers} workers.")
    print(f"Results will be written to: {csv_path}")
    
    start_time = time.time() 
    futures = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [
            executor.submit(
                validate_label_events, 
                batch, 
                ccgce_table,
                output_dir, 
                csv_path    
            )
            for batch in batches
        ]
        
        for i, future in enumerate(concurrent.futures.as_completed(futures)):
            try:
                future.result() 
                print(f"\nCompleted batch {i + 1}/{num_batches}")
            except Exception as e:
                print(f"\nBatch {i + 1} failed with error: {str(e)}")
    
    end_time = time.time()
    print(f"\nAll batches processed. Total time: {end_time - start_time:.2f} seconds.")
    print(f"Consolidated results are in: {csv_path}")

    return csv_path

# %% [markdown]
# ## Validation Execution
# Set up parameters, fetch sample input label events, and run the validation.

# %%
#ccgce_table = "cash_banking_ml_eng.cash_connected_graph_change_event.edgy_test_20250601"
#ccgce_table = "cash_banking_ml_eng.cash_connected_graph_change_event.edgy_test_20250610"
#ccgce_table = "cash_banking_ml_eng.cash_connected_graph_change_event.edgy_test_20250618"
ccgce_table = "cash_banking_ml_eng.cash_connected_graph_change_event.edgy_test_20250626"

# %%
# Obtain the date range of BAU events in ccgce_table that can be meaningfully validated 
query = f"""
SELECT MIN(cash_connected_graph_change_event.effective_at_millis) AS min_effective_at,
    MIN(cash_connected_graph_change_event.published_at_millis) AS min_published_at,
    MAX(cash_connected_graph_change_event.effective_at_millis) AS max_effective_at,
    MAX(cash_connected_graph_change_event.published_at_millis) AS max_published_at
    from {ccgce_table}
WHERE cash_connected_graph_change_event.event_source_type = 'BAU'
AND cash_connected_graph_change_event.label_change is not null
"""
date_range_df = spark_query(query)
# Use the max of the earliest effective_at and published_at timestamps as the start time
start_time = pd.to_datetime(max(date_range_df[["min_effective_at", "min_published_at"]].iloc[0]), unit="ms")
# Use the min of the latest effective_at and published_at timestamps as the finish time
finish_time = pd.to_datetime(min(date_range_df[["max_effective_at", "max_published_at"]].iloc[0]), unit="ms")
print(f"Edgy output time range to validate: {start_time} - {finish_time}")
# Out:
# Edgy output time range to validate: 2025-06-26 00:00:02.829000 - 2025-06-26 23:59:57.430000

# %%
# Fetch a sample of CASH_CUSTOMER labels from duplograph.public.label_events that were 
# created and became effective within the time range of the edgy output 
# (avoiding the boundaries in case of lag issues) 
query = f"""
SELECT 
    node_token, 
    label, 
    present, 
    effective_at
FROM duplograph.public.label_events 
WHERE node_type = 'CASH_CUSTOMER' 
AND effective_at BETWEEN '{start_time + pd.to_timedelta('8h')}' AND '{finish_time - pd.to_timedelta('8h')}'
AND created_at BETWEEN '{start_time + pd.to_timedelta('8h')}' AND '{finish_time - pd.to_timedelta('8h')}'
LIMIT 1000
"""
bau_labels_df = snowflake_query(query)
bau_labels_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>NODE_TOKEN</th>
#       <th>LABEL</th>
#       <th>PRESENT</th>
#       <th>EFFECTIVE_AT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>C_5xd810m63</td>
#       <td>HAS_ANY_CASH_DISPUTE</td>
#       <td>True</td>
#       <td>2025-06-26 09:22:03.000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>C_sxepcqywh</td>
#       <td>BLACKLISTED</td>
#       <td>True</td>
#       <td>2025-06-26 11:31:40.928</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C_fqd2kpmrq</td>
#       <td>BLACKLISTED</td>
#       <td>True</td>
#       <td>2025-06-26 08:03:53.813</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C_5mc6dgmaj</td>
#       <td>BLACKLISTED</td>
#       <td>True</td>
#       <td>2025-06-26 09:47:25.337</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>C_st2xppm3m</td>
#       <td>BLACKLISTED</td>
#       <td>True</td>
#       <td>2025-06-26 11:26:28.780</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>995</th>
#       <td>C_g42w9qytp</td>
#       <td>BLACKLISTED</td>
#       <td>True</td>
#       <td>2025-06-26 10:23:34.680</td>
#     </tr>
#     <tr>
#       <th>996</th>
#       <td>C_5j20ahmp8</td>
#       <td>BLACKLISTED</td>
#       <td>True</td>
#       <td>2025-06-26 08:03:27.784</td>
#     </tr>
#     <tr>
#       <th>997</th>
#       <td>C_ss2aphyj1</td>
#       <td>BLACKLISTED</td>
#       <td>True</td>
#       <td>2025-06-26 13:26:26.645</td>
#     </tr>
#     <tr>
#       <th>998</th>
#       <td>C_5s2zx8mpe</td>
#       <td>HAS_CASH_CHECK_RETURNS</td>
#       <td>True</td>
#       <td>2025-06-26 09:21:27.994</td>
#     </tr>
#     <tr>
#       <th>999</th>
#       <td>C_g0ewppmf8</td>
#       <td>BLACKLISTED</td>
#       <td>True</td>
#       <td>2025-06-26 12:00:38.563</td>
#     </tr>
#   </tbody>
# </table>
# <p>1000 rows × 4 columns</p>
# </div>

# %%
# Convert DataFrame rows to a set of label event tuples for validation
label_events_to_validate = set(
    bau_labels_df
      .assign(
        EFFECTIVE_AT=lambda df: pd.to_datetime(df["EFFECTIVE_AT"]).astype("int64") // 1_000_000
      )
      [["NODE_TOKEN", "LABEL", "PRESENT", "EFFECTIVE_AT"]]
      .itertuples(index=False, name=None)
)

# Run validation in batches
output_file = validate_label_events_batch(
    label_events_set=label_events_to_validate,
    ccgce_table=ccgce_table,
    output_dir="bau_label_validation",
    batch_size=10, 
    max_workers=10
)
# Out:
# Processing 1000 unique input label events in 100 batches of up to size 10, using 10 workers.
# Results will be written to: bau_label_validation/bau_label_validation_20250701_021110.csv
# Validating 10 unique input label events.
# - C_5nepxgmae -> HAS_CASH_CARD_DISPUTE=True @ 1750941726000
# - C_59eb20mzg -> BLACKLISTED=True @ 1750941715950
# - C_fscvx1mw7 -> HAS_CASH_CHECK_RETURNS=False @ 1750949045646
# - C_8scjxhmee -> BLACKLISTED=True @ 1750933848926
# - C_she8k8yr4 -> BLACKLISTED=True @ 1750944694979
# - C_fa2dchyy2 -> HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE=True @ 1750931647000
# - C_54e1dqm68 -> BLACKLISTED=True @ 1750951248958
# - C_5sebahmsz -> BLACKLISTED=True @ 1750939739817
# - C_gydyd1ynh -> BLACKLISTED=True @ 1750950239355
# - C_hx2tj1y42 -> HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE=True @ 1750942568000
#
# Processing input event 1/10: C_5nepxgmae/HAS_CASH_CARD_DISPUTE/True/1750941726000, effective_at=2025-06-26 12:42:06
# Validating 10 unique input label events.
# - C_hy2zrhydw -> BLACKLISTED=True @ 1750948204589
# - C_06dyjgm4f -> BLACKLISTED=True @ 1750930131571
# - C_h6cke1mrm -> BLACKLISTED=True @ 1750932938828
# - C_5scxpqmm5 -> HAS_ANY_CASH_DISPUTE=True @ 1750936066000
# - C_5hp0rqyas -> HAS_ANY_CASH_DISPUTE=True @ 1750947734000
# - C_5jefd0mvg -> BLACKLISTED=True @ 1750942111179
# - C_5me1eqmka -> BLACKLISTED=True @ 1750950490171
# - C_0npjrgyn5 -> BLACKLISTED=True @ 1750946745679
# - C_njd9pqmrw -> BLACKLISTED=True @ 1750941319372
# - C_5jeg2amr8 -> BLACKLISTED=True @ 1750949466327
#
# Processing input event 1/10: C_hy2zrhydw/BLACKLISTED/True/1750948204589, effective_at=2025-06-26 14:30:04.589000
# Validating 10 unique input label events.
# - C_hs2ja1mdc -> BLACKLISTED=True @ 1750946181287
# - C_f42wcpyva -> HAS_CASH_CHECK_RETURNS=False @ 1750948944676
# - C_8ydx41y2x -> HAS_ANY_CASH_DISPUTE=True @ 1750943432000
# - C_54e3c0mv8 -> BLACKLISTED=True @ 1750951116919
# - C_ss29w0m6w -> BLACKLISTED=True @ 1750933615948
# - C_862bx8m1p -> BLACKLISTED=True @ 1750951849697
# - C_gap7k0y2d -> HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE=True @ 1750945604000
# - C_8mdsx0mga -> BLACKLISTED=True @ 1750947255732
# - C_00d5j1y37 -> HAS_ANY_CASH_DISPUTE=True @ 1750948190000
# - C_gc2c28y4z -> BLACKLISTED=True @ 1750947563921
#
# Processing input event 1/10: C_hs2ja1mdc/BLACKLISTED/True/1750946181287, effective_at=2025-06-26 13:56:21.287000
# Validating 10 unique input label events.
# - C_0nc5rhyf2 -> BLACKLISTED=True @ 1750938982725
# - C_hsczapy4j -> BLACKLISTED=True @ 1750939819044
# - C_0sczx1y8m -> BLACKLISTED=True @ 1750930489937
# - C_0ac5w1yj7 -> HAS_ANY_CASH_DISPUTE=True @ 1750951240000
# - C_f4efdhm83 -> BLACKLISTED=True @ 1750951641378
# - C_nqcyxpmfy -> BLACKLISTED=True @ 1750936402594
# - C_0s2ajhm2r -> HAS_CASH_CHECK_RETURNS=False @ 1750949017920
# - C_f0dxqhy2d -> BLACKLISTED=True @ 1750943944057
# - C_s0efeamn1 -> BLACKLISTED=True @ 1750926521272
# - C_5jd1wqmrn -> BLACKLISTED=True @ 1750947205799
#
# Processing input event 1/10: C_0nc5rhyf2/BLACKLISTED/True/1750938982725, effective_at=2025-06-26 11:56:22.725000
# Validating 10 unique input label events.
# - C_84ccr8m3s -> BLACKLISTED=True @ 1750946495038
# - C_hqe1dqm8h -> BLACKLISTED=True @ 1750947919295
# - C_gqcgxhmj8 -> BLACKLISTED=True @ 1750935081214
# - C_fmdfp1mqc -> BLACKLISTED=True @ 1750947066759
# - C_0sdce1ycg -> BLACKLISTED=True @ 1750935610085
# - C_hacwk0myc -> BLACKLISTED=True @ 1750942492740
# - C_n62pagm5t -> HAS_CASH_CARD_DISPUTE=True @ 1750934301000
# - C_0e2t41yjt -> HAS_CASH_CHECK_RETURNS=False @ 1750948886133
# - C_nqdkxamny -> BLACKLISTED=True @ 1750930481516
# - C_5qc62amw1 -> BLACKLISTED=True @ 1750939027290
#
# Processing input event 1/10: C_84ccr8m3s/BLACKLISTED/True/1750946495038, effective_at=2025-06-26 14:01:35.038000
# Validating 10 unique input label events.
# - C_n02waqm42 -> HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE=True @ 1750950093000
# - C_gsd6whme3 -> BLACKLISTED=True @ 1750946499403
# - C_nt251hm24 -> BLACKLISTED=True @ 1750943672960
# - C_sneck0ydv -> BLACKLISTED=True @ 1750936964616
# - C_sseg28m2z -> BLACKLISTED=True @ 1750943872835
# - C_hx2tj1y42 -> HAS_CASH_CARD_DISPUTE=True @ 1750942568000
# - C_0ndnb0yq7 -> BLACKLISTED=True @ 1750927228174
# - C_snc54qyg0 -> HAS_ANY_CASH_DISPUTE=True @ 1750946054000
# - C_8aet1qyxk -> BLACKLISTED=True @ 1750925847453
# - C_5ydnepmxr -> BLACKLISTED=True @ 1750934578427
# Validating 10 unique input label events.
# - C_hj2bapmtt -> BLACKLISTED=True @ 1750930520679
# - C_5xp3r8ys5 -> BLACKLISTED=True @ 1750949796172
# - C_fnepxamr8 -> BLACKLISTED=True @ 1750953573851
# - C_89efeamy3 -> BLACKLISTED=True @ 1750938280500
# - C_fcpkrqyej -> HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE=True @ 1750939284000
# - C_8ecdr1y0r -> BLACKLISTED=True @ 1750952898973
# - C_f42fpqm9n -> BLACKLISTED=True @ 1750938436432
# - C_g0ezkgm2k -> HAS_EV_SUSPENSION=False @ 1750947659098
# - C_09ebcama1 -> BLACKLISTED=True @ 1750933776511
# - C_80d7xamr9 -> BLACKLISTED=True @ 1750951455794
#
# Processing input event 1/10: C_n02waqm42/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750950093000, effective_at=2025-06-26 15:01:33
# Validating 10 unique input label events.
# - C_fy2t91yvf -> HAS_ANY_CASH_DISPUTE=True @ 1750931187000
# - C_5qereqmky -> BLACKLISTED=True @ 1750935888165
# - C_h0ctq8yda -> HAS_ANY_CASH_DISPUTE=True @ 1750941193000
# - C_0e2hbhm9r -> BLACKLISTED=True @ 1750927578540
# - C_gs2p1hy9j -> BLACKLISTED=True @ 1750933608047
# - C_0qebehm1h -> BLACKLISTED=True @ 1750945941352
# - C_h4d8rpy37 -> HAS_CASH_CARD_DISPUTE=True @ 1750946093000
# - C_f6crc0m6p -> BLACKLISTED=True @ 1750936466857
# - C_scc210ygm -> BLACKLISTED=True @ 1750950333910
# - C_h6ckx1m30 -> BLACKLISTED=True @ 1750939313737
#
# Processing input event 1/10: C_hj2bapmtt/BLACKLISTED/True/1750930520679, effective_at=2025-06-26 09:35:20.679000
# Validating 10 unique input label events.
# - C_sjdapay9a -> BLACKLISTED=True @ 1750942283507
# - C_ha2zjhy29 -> BLACKLISTED=True @ 1750951357400
# - C_s6ecbqmhx -> BLACKLISTED=True @ 1750946922483
# - C_0hdxd8yex -> HAS_ANY_CASH_DISPUTE=True @ 1750949575000
# - C_8mc2jayz2 -> BLACKLISTED=True @ 1750927127433
# - C_8tc8egyac -> HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE=True @ 1750946219000
# - C_fhdzepyqh -> HAS_CASH_CARD_DISPUTE=True @ 1750932608000
# - C_0tdhk8y1t -> BLACKLISTED=True @ 1750943203095
# - C_n0ekehmy3 -> BLACKLISTED=True @ 1750940470597
# - C_0sd1a1msj -> BLACKLISTED=True @ 1750945023575
#
# Processing input event 1/10: C_sjdapay9a/BLACKLISTED/True/1750942283507, effective_at=2025-06-26 12:51:23.507000
#
# Processing input event 1/10: C_fy2t91yvf/HAS_ANY_CASH_DISPUTE/True/1750931187000, effective_at=2025-06-26 09:46:27
# Validating 10 unique input label events.
# - C_09edphmsn -> HAS_CASH_CHECK_RETURNS=True @ 1750929695102
# - C_04eheqy6x -> HAS_EV_SUSPENSION=False @ 1750944296042
# - C_8sea2pmc3 -> BLACKLISTED=True @ 1750944294392
# - C_f42ba1mxd -> BLACKLISTED=True @ 1750946087418
# - C_0sddc0mw1 -> BLACKLISTED=True @ 1750943042915
# - C_0eetw1mx4 -> BLACKLISTED=True @ 1750931837573
# - C_feex20y5d -> BLACKLISTED=True @ 1750926128476
# - C_g4cxwam9e -> HAS_CASH_CHECK_RETURNS=False @ 1750949045490
# - C_0tdn4pyf1 -> BLACKLISTED=True @ 1750937260123
# - C_00dx1hy9w -> HAS_CASH_CARD_DISPUTE=True @ 1750953550000
#
# Processing input event 1/10: C_09edphmsn/HAS_CASH_CHECK_RETURNS/True/1750929695102, effective_at=2025-06-26 09:21:35.102000
# Time to validate event C_hj2bapmtt/BLACKLISTED/True/1750930520679: 11.31 seconds
# ℹ️ Label Event C_hj2bapmtt/BLACKLISTED/True/1750930520679: Input label event resulted in NO_CHANGE to AH AH_pcm0whcnn's active labels for BLACKLISTED. No events expected.
#
# Processing input event 2/10: C_5xp3r8ys5/BLACKLISTED/True/1750949796172, effective_at=2025-06-26 14:56:36.172000
# Time to validate event C_hs2ja1mdc/BLACKLISTED/True/1750946181287: 13.72 seconds
# ℹ️ Label Event C_hs2ja1mdc/BLACKLISTED/True/1750946181287: Input label event resulted in NO_CHANGE to AH AH_x4m8wk2mn's active labels for BLACKLISTED. No events expected.
#
# Processing input event 2/10: C_f42wcpyva/HAS_CASH_CHECK_RETURNS/False/1750948944676, effective_at=2025-06-26 14:42:24.676000
# Time to validate event C_0nc5rhyf2/BLACKLISTED/True/1750938982725: 14.32 seconds
# ℹ️ Label Event C_0nc5rhyf2/BLACKLISTED/True/1750938982725: All validations passed
#
# Processing input event 2/10: C_hsczapy4j/BLACKLISTED/True/1750939819044, effective_at=2025-06-26 12:10:19.044000
# Time to validate event C_fy2t91yvf/HAS_ANY_CASH_DISPUTE/True/1750931187000: 24.24 seconds
# ℹ️ Label Event C_fy2t91yvf/HAS_ANY_CASH_DISPUTE/True/1750931187000: All validations passed
#
# Processing input event 2/10: C_5qereqmky/BLACKLISTED/True/1750935888165, effective_at=2025-06-26 11:04:48.165000
# Time to validate event C_09edphmsn/HAS_CASH_CHECK_RETURNS/True/1750929695102: 26.69 seconds
# ℹ️ Label Event C_09edphmsn/HAS_CASH_CHECK_RETURNS/True/1750929695102: All validations passed
#
# Processing input event 2/10: C_04eheqy6x/HAS_EV_SUSPENSION/False/1750944296042, effective_at=2025-06-26 13:24:56.042000
# Time to validate event C_f42wcpyva/HAS_CASH_CHECK_RETURNS/False/1750948944676: 15.20 seconds
# ℹ️ Label Event C_f42wcpyva/HAS_CASH_CHECK_RETURNS/False/1750948944676: Input label event resulted in NO_CHANGE to AH AH_avypcw24f's active labels for HAS_CASH_CHECK_RETURNS. No events expected.
#
# Processing input event 3/10: C_8ydx41y2x/HAS_ANY_CASH_DISPUTE/True/1750943432000, effective_at=2025-06-26 13:10:32
# Time to validate event C_n02waqm42/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750950093000: 31.39 seconds
# ❌ Label Event C_n02waqm42/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750950093000: Validation failed
#
# Unexpected events (6):
#   - L/AH_00y1phcn5/AH_24mqaw20n/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750950093000/+
#   - L/AH_9kyaahdqs/AH_24mqaw20n/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750950093000/+
#   - L/AH_m2ypw5d48/AH_24mqaw20n/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750950093000/+
#   - L/AH_ncmg9wex0/AH_24mqaw20n/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750950093000/+
#   - L/AH_pky0e2dn8/AH_24mqaw20n/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750950093000/+
#   - L/AH_zmy1edecs/AH_24mqaw20n/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750950093000/+
#
# Processing input event 2/10: C_gsd6whme3/BLACKLISTED/True/1750946499403, effective_at=2025-06-26 14:01:39.403000
# Time to validate event C_sjdapay9a/BLACKLISTED/True/1750942283507: 33.65 seconds
# ℹ️ Label Event C_sjdapay9a/BLACKLISTED/True/1750942283507: All validations passed
#
# Processing input event 2/10: C_ha2zjhy29/BLACKLISTED/True/1750951357400, effective_at=2025-06-26 15:22:37.400000
# Time to validate event C_5nepxgmae/HAS_CASH_CARD_DISPUTE/True/1750941726000: 33.68 seconds
# ❌ Label Event C_5nepxgmae/HAS_CASH_CARD_DISPUTE/True/1750941726000: Validation failed
#
# Unexpected events (1):
#   - L/AH_19m1p5ets/AH_eamgxpen5/HAS_CASH_CARD_DISPUTE/1750941726000/+
#
# Processing input event 2/10: C_59eb20mzg/BLACKLISTED/True/1750941715950, effective_at=2025-06-26 12:41:55.950000
# Time to validate event C_hy2zrhydw/BLACKLISTED/True/1750948204589: 35.46 seconds
# ℹ️ Label Event C_hy2zrhydw/BLACKLISTED/True/1750948204589: All validations passed
#
# Processing input event 2/10: C_06dyjgm4f/BLACKLISTED/True/1750930131571, effective_at=2025-06-26 09:28:51.571000
# Time to validate event C_5xp3r8ys5/BLACKLISTED/True/1750949796172: 25.12 seconds
# ℹ️ Label Event C_5xp3r8ys5/BLACKLISTED/True/1750949796172: All validations passed
#
# Processing input event 3/10: C_fnepxamr8/BLACKLISTED/True/1750953573851, effective_at=2025-06-26 15:59:33.851000
# Time to validate event C_84ccr8m3s/BLACKLISTED/True/1750946495038: 36.52 seconds
# ℹ️ Label Event C_84ccr8m3s/BLACKLISTED/True/1750946495038: All validations passed
#
# Processing input event 2/10: C_hqe1dqm8h/BLACKLISTED/True/1750947919295, effective_at=2025-06-26 14:25:19.295000
# Time to validate event C_hsczapy4j/BLACKLISTED/True/1750939819044: 25.82 seconds
# ℹ️ Label Event C_hsczapy4j/BLACKLISTED/True/1750939819044: All validations passed
#
# Processing input event 3/10: C_0sczx1y8m/BLACKLISTED/True/1750930489937, effective_at=2025-06-26 09:34:49.937000
# Time to validate event C_5qereqmky/BLACKLISTED/True/1750935888165: 18.25 seconds
# ℹ️ Label Event C_5qereqmky/BLACKLISTED/True/1750935888165: Input label event resulted in NO_CHANGE to AH AH_ykmqereq5's active labels for BLACKLISTED. No events expected.
#
# Processing input event 3/10: C_h0ctq8yda/HAS_ANY_CASH_DISPUTE/True/1750941193000, effective_at=2025-06-26 12:33:13
# Time to validate event C_gsd6whme3/BLACKLISTED/True/1750946499403: 14.95 seconds
# ℹ️ Label Event C_gsd6whme3/BLACKLISTED/True/1750946499403: Input label event resulted in NO_CHANGE to AH AH_80mqp1d6h's active labels for BLACKLISTED. No events expected.
#
# Processing input event 3/10: C_nt251hm24/BLACKLISTED/True/1750943672960, effective_at=2025-06-26 13:14:32.960000
# Time to validate event C_04eheqy6x/HAS_EV_SUSPENSION/False/1750944296042: 22.68 seconds
# ℹ️ Label Event C_04eheqy6x/HAS_EV_SUSPENSION/False/1750944296042: All validations passed
#
# Processing input event 3/10: C_8sea2pmc3/BLACKLISTED/True/1750944294392, effective_at=2025-06-26 13:24:54.392000
# Time to validate event C_ha2zjhy29/BLACKLISTED/True/1750951357400: 15.74 seconds
# ℹ️ Label Event C_ha2zjhy29/BLACKLISTED/True/1750951357400: Input label event resulted in NO_CHANGE to AH AH_4eyhjp2xh's active labels for BLACKLISTED. No events expected.
#
# Processing input event 3/10: C_s6ecbqmhx/BLACKLISTED/True/1750946922483, effective_at=2025-06-26 14:08:42.483000
# Time to validate event C_8ydx41y2x/HAS_ANY_CASH_DISPUTE/True/1750943432000: 22.57 secondsTime to validate event C_0sczx1y8m/BLACKLISTED/True/1750930489937: 11.37 seconds
# ℹ️ Label Event C_0sczx1y8m/BLACKLISTED/True/1750930489937: Input label event resulted in NO_CHANGE to AH AH_m8y1xzcs0's active labels for BLACKLISTED. No events expected.
#
# ℹ️ Label Event C_8ydx41y2x/HAS_ANY_CASH_DISPUTE/True/1750943432000: All validations passed
#
# Processing input event 4/10: C_54e3c0mv8/BLACKLISTED/True/1750951116919, effective_at=2025-06-26 15:18:36.919000
#
# Processing input event 4/10: C_0ac5w1yj7/HAS_ANY_CASH_DISPUTE/True/1750951240000, effective_at=2025-06-26 15:20:40
# Time to validate event C_59eb20mzg/BLACKLISTED/True/1750941715950: 21.06 seconds
# ℹ️ Label Event C_59eb20mzg/BLACKLISTED/True/1750941715950: All validations passed
#
# Processing input event 3/10: C_fscvx1mw7/HAS_CASH_CHECK_RETURNS/False/1750949045646, effective_at=2025-06-26 14:44:05.646000
# Time to validate event C_hqe1dqm8h/BLACKLISTED/True/1750947919295: 22.96 seconds
# ℹ️ Label Event C_hqe1dqm8h/BLACKLISTED/True/1750947919295: All validations passed
#
# Processing input event 3/10: C_gqcgxhmj8/BLACKLISTED/True/1750935081214, effective_at=2025-06-26 10:51:21.214000
# Time to validate event C_06dyjgm4f/BLACKLISTED/True/1750930131571: 25.71 seconds
# ℹ️ Label Event C_06dyjgm4f/BLACKLISTED/True/1750930131571: All validations passed
#
# Processing input event 3/10: C_h6cke1mrm/BLACKLISTED/True/1750932938828, effective_at=2025-06-26 10:15:38.828000
# Time to validate event C_nt251hm24/BLACKLISTED/True/1750943672960: 14.99 seconds
# ℹ️ Label Event C_nt251hm24/BLACKLISTED/True/1750943672960: Input label event resulted in NO_CHANGE to AH AH_42mh152tn's active labels for BLACKLISTED. No events expected.
#
# Processing input event 4/10: C_sneck0ydv/BLACKLISTED/True/1750936964616, effective_at=2025-06-26 11:22:44.616000
# Time to validate event C_fnepxamr8/BLACKLISTED/True/1750953573851: 26.09 seconds
# ℹ️ Label Event C_fnepxamr8/BLACKLISTED/True/1750953573851: All validations passed
#
# Processing input event 4/10: C_89efeamy3/BLACKLISTED/True/1750938280500, effective_at=2025-06-26 11:44:40.500000
# Time to validate event C_8sea2pmc3/BLACKLISTED/True/1750944294392: 16.04 seconds
# ℹ️ Label Event C_8sea2pmc3/BLACKLISTED/True/1750944294392: Input label event resulted in NO_CHANGE to AH AH_3cmp2aes8's active labels for BLACKLISTED. No events expected.
#
# Processing input event 4/10: C_f42ba1mxd/BLACKLISTED/True/1750946087418, effective_at=2025-06-26 13:54:47.418000
# Time to validate event C_fscvx1mw7/HAS_CASH_CHECK_RETURNS/False/1750949045646: 16.22 seconds
# ℹ️ Label Event C_fscvx1mw7/HAS_CASH_CHECK_RETURNS/False/1750949045646: Input label event resulted in NO_CHANGE to AH AH_7wm1xvcsf's active labels for HAS_CASH_CHECK_RETURNS. No events expected.
#
# Processing input event 4/10: C_8scjxhmee/BLACKLISTED/True/1750933848926, effective_at=2025-06-26 10:30:48.926000
# Time to validate event C_s6ecbqmhx/BLACKLISTED/True/1750946922483: 22.19 seconds
# ℹ️ Label Event C_s6ecbqmhx/BLACKLISTED/True/1750946922483: All validations passed
#
# Processing input event 4/10: C_0hdxd8yex/HAS_ANY_CASH_DISPUTE/True/1750949575000, effective_at=2025-06-26 14:52:55
# Time to validate event C_0ac5w1yj7/HAS_ANY_CASH_DISPUTE/True/1750951240000: 22.37 seconds
# ℹ️ Label Event C_0ac5w1yj7/HAS_ANY_CASH_DISPUTE/True/1750951240000: All validations passed
#
# Processing input event 5/10: C_f4efdhm83/BLACKLISTED/True/1750951641378, effective_at=2025-06-26 15:27:21.378000
# Time to validate event C_h6cke1mrm/BLACKLISTED/True/1750932938828: 12.72 seconds
# ℹ️ Label Event C_h6cke1mrm/BLACKLISTED/True/1750932938828: Input label event resulted in NO_CHANGE to AH AH_mbmq2se6s's active labels for BLACKLISTED. No events expected.
#
# Processing input event 4/10: C_5scxpqmm5/HAS_ANY_CASH_DISPUTE/True/1750936066000, effective_at=2025-06-26 11:07:46
# Time to validate event C_54e3c0mv8/BLACKLISTED/True/1750951116919: 22.57 seconds
# ℹ️ Label Event C_54e3c0mv8/BLACKLISTED/True/1750951116919: All validations passed
#
# Processing input event 5/10: C_ss29w0m6w/BLACKLISTED/True/1750933615948, effective_at=2025-06-26 10:26:55.948000
# Time to validate event C_sneck0ydv/BLACKLISTED/True/1750936964616: 18.33 seconds
# ℹ️ Label Event C_sneck0ydv/BLACKLISTED/True/1750936964616: Source AH AH_vdy0kcens has no connected target AHs. No events expected.
#
# Processing input event 5/10: C_sseg28m2z/BLACKLISTED/True/1750943872835, effective_at=2025-06-26 13:17:52.835000
# Time to validate event C_gqcgxhmj8/BLACKLISTED/True/1750935081214: 20.60 seconds
# ℹ️ Label Event C_gqcgxhmj8/BLACKLISTED/True/1750935081214: All validations passed
#
# Processing input event 4/10: C_fmdfp1mqc/BLACKLISTED/True/1750947066759, effective_at=2025-06-26 14:11:06.759000
# Time to validate event C_f42ba1mxd/BLACKLISTED/True/1750946087418: 14.83 seconds
# ℹ️ Label Event C_f42ba1mxd/BLACKLISTED/True/1750946087418: Input label event resulted in NO_CHANGE to AH AH_dxm1ab24f's active labels for BLACKLISTED. No events expected.
#
# Processing input event 5/10: C_0sddc0mw1/BLACKLISTED/True/1750943042915, effective_at=2025-06-26 13:04:02.915000
# Time to validate event C_89efeamy3/BLACKLISTED/True/1750938280500: 20.73 seconds
# ℹ️ Label Event C_89efeamy3/BLACKLISTED/True/1750938280500: All validations passed
#
# Processing input event 5/10: C_fcpkrqyej/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750939284000, effective_at=2025-06-26 12:01:24
# Time to validate event C_8scjxhmee/BLACKLISTED/True/1750933848926: 13.96 seconds
# ℹ️ Label Event C_8scjxhmee/BLACKLISTED/True/1750933848926: Input label event resulted in NO_CHANGE to AH AH_eemhxjcs8's active labels for BLACKLISTED. No events expected.
#
# Processing input event 5/10: C_she8k8yr4/BLACKLISTED/True/1750944694979, effective_at=2025-06-26 13:31:34.979000
# Time to validate event C_0hdxd8yex/HAS_ANY_CASH_DISPUTE/True/1750949575000: 20.97 seconds
# ℹ️ Label Event C_0hdxd8yex/HAS_ANY_CASH_DISPUTE/True/1750949575000: All validations passed
#
# Processing input event 5/10: C_8mc2jayz2/BLACKLISTED/True/1750927127433, effective_at=2025-06-26 08:38:47.433000
# Time to validate event C_fmdfp1mqc/BLACKLISTED/True/1750947066759: 13.46 seconds
# ℹ️ Label Event C_fmdfp1mqc/BLACKLISTED/True/1750947066759: Input label event resulted in NO_CHANGE to AH AH_cqm1pfdmf's active labels for BLACKLISTED. No events expected.
#
# Processing input event 5/10: C_0sdce1ycg/BLACKLISTED/True/1750935610085, effective_at=2025-06-26 11:00:10.085000
# Time to validate event C_f4efdhm83/BLACKLISTED/True/1750951641378: 21.25 seconds
# ℹ️ Label Event C_f4efdhm83/BLACKLISTED/True/1750951641378: All validations passed
#
# Processing input event 6/10: C_nqcyxpmfy/BLACKLISTED/True/1750936402594, effective_at=2025-06-26 11:13:22.594000
# Time to validate event C_5scxpqmm5/HAS_ANY_CASH_DISPUTE/True/1750936066000: 21.34 seconds
# ℹ️ Label Event C_5scxpqmm5/HAS_ANY_CASH_DISPUTE/True/1750936066000: All validations passed
#
# Processing input event 5/10: C_5hp0rqyas/HAS_ANY_CASH_DISPUTE/True/1750947734000, effective_at=2025-06-26 14:22:14
# Time to validate event C_sseg28m2z/BLACKLISTED/True/1750943872835: 15.62 seconds
# ℹ️ Label Event C_sseg28m2z/BLACKLISTED/True/1750943872835: Input label event resulted in NO_CHANGE to AH AH_yjma9z2hn's active labels for BLACKLISTED. No events expected.
#
# Processing input event 6/10: C_hx2tj1y42/HAS_CASH_CARD_DISPUTE/True/1750942568000, effective_at=2025-06-26 12:56:08
# Time to validate event C_ss29w0m6w/BLACKLISTED/True/1750933615948: 22.24 seconds
# ℹ️ Label Event C_ss29w0m6w/BLACKLISTED/True/1750933615948: All validations passed
#
# Processing input event 6/10: C_862bx8m1p/BLACKLISTED/True/1750951849697, effective_at=2025-06-26 15:30:49.697000
# Time to validate event C_0sddc0mw1/BLACKLISTED/True/1750943042915: 19.22 seconds
# ℹ️ Label Event C_0sddc0mw1/BLACKLISTED/True/1750943042915: All validations passed
#
# Processing input event 6/10: C_0eetw1mx4/BLACKLISTED/True/1750931837573, effective_at=2025-06-26 09:57:17.573000
# Time to validate event C_fcpkrqyej/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750939284000: 20.83 seconds
# ℹ️ Label Event C_fcpkrqyej/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750939284000: All validations passed
#
# Processing input event 6/10: C_8ecdr1y0r/BLACKLISTED/True/1750952898973, effective_at=2025-06-26 15:48:18.973000
# Time to validate event C_she8k8yr4/BLACKLISTED/True/1750944694979: 20.75 seconds
# ℹ️ Label Event C_she8k8yr4/BLACKLISTED/True/1750944694979: All validations passed
#
# Processing input event 6/10: C_fa2dchyy2/HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE/True/1750931647000, effective_at=2025-06-26 09:54:07
# Time to validate event C_862bx8m1p/BLACKLISTED/True/1750951849697: 18.37 seconds
# ℹ️ Label Event C_862bx8m1p/BLACKLISTED/True/1750951849697: Input label event resulted in NO_CHANGE to AH AH_pam1wq20g's active labels for BLACKLISTED. No events expected.
#
# Processing input event 7/10: C_gap7k0y2d/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750945604000, effective_at=2025-06-26 13:46:44
# Time to validate event C_8mc2jayz2/BLACKLISTED/True/1750927127433: 22.99 seconds
# ℹ️ Label Event C_8mc2jayz2/BLACKLISTED/True/1750927127433: All validations passed
#
# Processing input event 6/10: C_8tc8egyac/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750946219000, effective_at=2025-06-26 13:56:59
# Time to validate event C_0sdce1ycg/BLACKLISTED/True/1750935610085: 23.27 seconds
# ℹ️ Label Event C_0sdce1ycg/BLACKLISTED/True/1750935610085: All validations passed
#
# Processing input event 6/10: C_hacwk0myc/BLACKLISTED/True/1750942492740, effective_at=2025-06-26 12:54:52.740000
# Time to validate event C_hx2tj1y42/HAS_CASH_CARD_DISPUTE/True/1750942568000: 22.61 seconds
# ℹ️ Label Event C_hx2tj1y42/HAS_CASH_CARD_DISPUTE/True/1750942568000: All validations passed
#
# Processing input event 7/10: C_0ndnb0yq7/BLACKLISTED/True/1750927228174, effective_at=2025-06-26 08:40:28.174000
# Time to validate event C_5hp0rqyas/HAS_ANY_CASH_DISPUTE/True/1750947734000: 22.93 seconds
# ℹ️ Label Event C_5hp0rqyas/HAS_ANY_CASH_DISPUTE/True/1750947734000: All validations passed
#
# Processing input event 6/10: C_5jefd0mvg/BLACKLISTED/True/1750942111179, effective_at=2025-06-26 12:48:31.179000
# Time to validate event C_8ecdr1y0r/BLACKLISTED/True/1750952898973: 14.10 seconds
# ℹ️ Label Event C_8ecdr1y0r/BLACKLISTED/True/1750952898973: Input label event resulted in NO_CHANGE to AH AH_01y1etdmh's active labels for BLACKLISTED. No events expected.
#
# Processing input event 7/10: C_f42fpqm9n/BLACKLISTED/True/1750938436432, effective_at=2025-06-26 11:47:16.432000
# Time to validate event C_nqcyxpmfy/BLACKLISTED/True/1750936402594: 23.07 seconds
# ℹ️ Label Event C_nqcyxpmfy/BLACKLISTED/True/1750936402594: All validations passed
#
# Processing input event 7/10: C_0s2ajhm2r/HAS_CASH_CHECK_RETURNS/False/1750949017920, effective_at=2025-06-26 14:43:37.920000
# Time to validate event C_0eetw1mx4/BLACKLISTED/True/1750931837573: 23.53 seconds
# ℹ️ Label Event C_0eetw1mx4/BLACKLISTED/True/1750931837573: All validations passed
#
# Processing input event 7/10: C_feex20y5d/BLACKLISTED/True/1750926128476, effective_at=2025-06-26 08:22:08.476000
# Time to validate event C_fa2dchyy2/HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE/True/1750931647000: 21.88 seconds
# ℹ️ Label Event C_fa2dchyy2/HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE/True/1750931647000: All validations passed
#
# Processing input event 7/10: C_54e1dqm68/BLACKLISTED/True/1750951248958, effective_at=2025-06-26 15:20:48.958000
# Time to validate event C_hacwk0myc/BLACKLISTED/True/1750942492740: 15.61 seconds
# ℹ️ Label Event C_hacwk0myc/BLACKLISTED/True/1750942492740: Input label event resulted in NO_CHANGE to AH AH_cym0kwcah's active labels for BLACKLISTED. No events expected
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# ECK_RETURNS/False/1750948886133: 13.69 seconds
# ℹ️ Label Event C_0e2t41yjt/HAS_CASH_CHECK_RETURNS/False/1750948886133: Input label event resulted in NO_CHANGE to AH AH_tjy14t2e0's active labels for HAS_CASH_CHECK_RETURNS. No events expected.
#
# Processing input event 9/10: C_nqdkxamny/BLACKLISTED/True/1750930481516, effective_at=2025-06-26 09:34:41.516000
# Time to validate event C_5sebahmsz/BLACKLISTED/True/1750939739817: 21.03 seconds
# ℹ️ Label Event C_5sebahmsz/BLACKLISTED/True/1750939739817: All validations passed
#
# Processing input event 9/10: C_gydyd1ynh/BLACKLISTED/True/1750950239355, effective_at=2025-06-26 15:03:59.355000
# Time to validate event C_0npjrgyn5/BLACKLISTED/True/1750946745679: 15.86 seconds
# ℹ️ Label Event C_0npjrgyn5/BLACKLISTED/True/1750946745679: Input label event resulted in NO_CHANGE to AH AH_5nygrjpn0's active labels for BLACKLISTED. No events expected.
#
# Processing input event 9/10: C_njd9pqmrw/BLACKLISTED/True/1750941319372, effective_at=2025-06-26 12:35:19.372000
# Time to validate event C_00d5j1y37/HAS_ANY_CASH_DISPUTE/True/1750948190000: 20.78 seconds
# ℹ️ Label Event C_00d5j1y37/HAS_ANY_CASH_DISPUTE/True/1750948190000: All validations passed
#
# Processing input event 10/10: C_gc2c28y4z/BLACKLISTED/True/1750947563921, effective_at=2025-06-26 14:19:23.921000
# Time to validate event C_0tdn4pyf1/BLACKLISTED/True/1750937260123: 16.03 seconds
# ℹ️ Label Event C_0tdn4pyf1/BLACKLISTED/True/1750937260123: Input label event resulted in NO_CHANGE to AH AH_70mpx8dn5's active labels for BLACKLISTED. No events expected.
#
# Processing input event 10/10: C_00dx1hy9w/HAS_CASH_CARD_DISPUTE/True/1750953550000, effective_at=2025-06-26 15:59:10
# Time to validate event C_0tdhk8y1t/BLACKLISTED/True/1750943203095: 13.89 seconds
# ℹ️ Label Event C_0tdhk8y1t/BLACKLISTED/True/1750943203095: Input label event resulted in NO_CHANGE to AH AH_3cmhqyct8's active labels for BLACKLISTED. No events expected.
#
# Processing input event 9/10: C_n0ekehmy3/BLACKLISTED/True/1750940470597, effective_at=2025-06-26 12:21:10.597000
# Time to validate event C_09ebcama1/BLACKLISTED/True/1750933776511: 15.48 seconds
# ℹ️ Label Event C_09ebcama1/BLACKLISTED/True/1750933776511: Source AH AH_1amacbe90 has no connected target AHs. No events expected.
#
# Processing input event 10/10: C_80d7xamr9/BLACKLISTED/True/1750951455794, effective_at=2025-06-26 15:24:15.794000
# Time to validate event C_8aet1qyxk/BLACKLISTED/True/1750925847453: 19.55 seconds
# ℹ️ Label Event C_8aet1qyxk/BLACKLISTED/True/1750925847453: All validations passed
#
# Processing input event 10/10: C_5ydnepmxr/BLACKLISTED/True/1750934578427, effective_at=2025-06-26 10:42:58.427000
# Time to validate event C_5jd1wqmrn/BLACKLISTED/True/1750947205799: 13.06 seconds
# ℹ️ Label Event C_5jd1wqmrn/BLACKLISTED/True/1750947205799: Input label event resulted in NO_CHANGE to AH AH_gzmpwcc6f's active labels for BLACKLISTED. No events expected.
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 17.75 seconds
# - Fastest validation: 11.37 seconds
# - Slowest validation: 25.82 seconds
# - Total validation time for this batch: 177.52 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
# Validating 10 unique input label events.
# - C_na2d48ynn -> BLACKLISTED=True @ 1750927360081
# - C_hn2trayta -> BLACKLISTED=True @ 1750947357545
# - C_hmdbwhme6 -> BLACKLISTED=True @ 1750937937956
# - C_5q2nxpme5 -> HAS_ANY_CASH_DISPUTE=True @ 1750946650000
# - C_sxc2phycx -> BLACKLISTED=True @ 1750937901095
# - C_gm2jp1mx7 -> BLACKLISTED=True @ 1750946904418
# - C_hhepqpy81 -> BLACKLISTED=True @ 1750926498485
# - C_gsc3w0m3n -> BLACKLISTED=True @ 1750929122221
# - C_8jeqcqm23 -> BLACKLISTED=True @ 1750944224208
# - C_n6e7w0my4 -> BLACKLISTED=True @ 1750947320208
#
# Processing input event 1/10: C_na2d48ynn/BLACKLISTED/True/1750927360081, effective_at=2025-06-26 08:42:40.081000
#
# Completed batch 1/100
# Time to validate event C_nqdkxamny/BLACKLISTED/True/1750930481516: 13.53 seconds
# ℹ️ Label Event C_nqdkxamny/BLACKLISTED/True/1750930481516: Input label event resulted in NO_CHANGE to AH AH_ymmqx4d65's active labels for BLACKLISTED. No events expected.
#
# Processing input event 10/10: C_5qc62amw1/BLACKLISTED/True/1750939027290, effective_at=2025-06-26 11:57:07.290000
# Time to validate event C_gydyd1ynh/BLACKLISTED/True/1750950239355: 12.74 seconds
# ℹ️ Label Event C_gydyd1ynh/BLACKLISTED/True/1750950239355: Input label event resulted in NO_CHANGE to AH AH_hny1dydyg's active labels for BLACKLISTED. No events expected.
#
# Processing input event 10/10: C_hx2tj1y42/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750942568000, effective_at=2025-06-26 12:56:08
# Time to validate event C_njd9pqmrw/BLACKLISTED/True/1750941319372: 12.12 seconds
# ℹ️ Label Event C_njd9pqmrw/BLACKLISTED/True/1750941319372: Input label event resulted in NO_CHANGE to AH AH_wrmqp9djn's active labels for BLACKLISTED. No events expected.
#
# Processing input event 10/10: C_5jeg2amr8/BLACKLISTED/True/1750949466327, effective_at=2025-06-26 14:51:06.327000
# Time to validate event C_n0ekehmy3/BLACKLISTED/True/1750940470597: 13.20 seconds
# ℹ️ Label Event C_n0ekehmy3/BLACKLISTED/True/1750940470597: Input label event resulted in NO_CHANGE to AH AH_hpyg4w2a5's active labels for BLACKLISTED. No events expected.
#
# Processing input event 10/10: C_0sd1a1msj/BLACKLISTED/True/1750945023575, effective_at=2025-06-26 13:37:03.575000
# Time to validate event C_00dx1hy9w/HAS_CASH_CARD_DISPUTE/True/1750953550000: 21.46 seconds
# ℹ️ Label Event C_00dx1hy9w/HAS_CASH_CARD_DISPUTE/True/1750953550000: All validations passed
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 19.39 seconds
# - Fastest validation: 14.83 seconds
# - Slowest validation: 26.69 seconds
# - Total validation time for this batch: 193.91 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
# Validating 10 unique input label events.
# - C_042zp0mb9 -> HAS_ANY_CASH_DISPUTE=True @ 1750945131000
# - C_h4cp4pmfh -> BLACKLISTED=True @ 1750927655935
# - C_nqdkxgm7n -> BLACKLISTED=True @ 1750948831337
# - C_f42tpqmq3 -> BLACKLISTED=True @ 1750948326281
# - C_0adddqy3k -> HAS_ANY_CASH_DISPUTE=True @ 1750939761000
# - C_092cphm9c -> HAS_CASH_CARD_DISPUTE=True @ 1750935636000
# - C_5s2zx8mpe -> HAS_CASH_CHECK_RETURNS=True @ 1750929687994
# - C_59ejcamd3 -> BLACKLISTED=True @ 1750942067493
# - C_0serc8mfe -> HAS_EV_SUSPENSION=True @ 1750949990461
# - C_89dd9qmgp -> BLACKLISTED=True @ 1750941980267
#
# Completed batch 2/100
#
# Processing input event 1/10: C_042zp0mb9/HAS_ANY_CASH_DISPUTE/True/1750945131000, effective_at=2025-06-26 13:38:51
# Time to validate event C_80d7xamr9/BLACKLISTED/True/1750951455794: 19.21 seconds
# ℹ️ Label Event C_80d7xamr9/BLACKLISTED/True/1750951455794: Input label event resulted in NO_CHANGE to AH AH_9rmax7d08's active labels for BLACKLISTED. No events expected.
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 19.45 seconds
# - Fastest validation: 11.31 seconds
# - Slowest validation: 26.09 seconds
# - Total validation time for this batch: 194.54 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
# Validating 10 unique input label events.
# - C_80dka8mas -> BLACKLISTED=True @ 1750936333813
# - C_8xpkrgyvp -> HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE=True @ 1750945100000
# - C_fj2swamya -> BLACKLISTED=True @ 1750937633678
# - C_sm24pqm8v -> BLACKLISTED=True @ 1750930878291
# - C_n025k0ysh -> BLACKLISTED=True @ 1750931382968
# - C_sq2drgymt -> HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE=True @ 1750927952000
# - C_nt251hm24 -> BLACKLISTED=True @ 1750931810758
# - C_gtdhcqyn8 -> BLACKLISTED=True @ 1750952441472
# - C_50e72qmdh -> BLACKLISTED=True @ 1750939583952
# - C_gj2jp0mk9 -> BLACKLISTED=True @ 1750935522179
#
# Processing input event 1/10: C_80dka8mas/BLACKLISTED/True/1750936333813, effective_at=2025-06-26 11:12:13.813000
#
# Completed batch 3/100
# Time to validate event C_gc2c28y4z/BLACKLISTED/True/1750947563921: 22.42 seconds
# ℹ️ Label Event C_gc2c28y4z/BLACKLISTED/True/1750947563921: All validations passed
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 19.48 seconds
# - Fastest validation: 13.72 seconds
# - Slowest validation: 22.57 seconds
# - Total validation time for this batch: 194.83 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
# Validating 10 unique input label events.
# - C_5xeep0yx6 -> BLACKLISTED=True @ 1750925484996
# - C_8cevdpyvz -> BLACKLISTED=True @ 1750948088773
# - C_gactc0yx9 -> HAS_EV_SUSPENSION=False @ 1750944943433
# - C_8ye2jhy33 -> BLACKLISTED=True @ 1750939781646
# - C_gj2wqpyve -> BLACKLISTED=True @ 1750944015378
# - C_h4dewhmav -> HAS_CASH_CARD_DISPUTE=True @ 1750946087000
# - C_nndzdhydh -> HAS_CASH_CARD_DISPUTE=True @ 1750942753000
# - C_5t2awgygs -> HAS_ANY_CASH_DISPUTE=True @ 1750938821000
# - C_84e020mz8 -> BLACKLISTED=True @ 1750950892105
# - C_fjd5kgm73 -> BLACKLISTED=True @ 1750937281016
#
# Completed batch 4/100
#
# Processing input event 1/10: C_5xeep0yx6/BLACKLISTED/True/1750925484996, effective_at=2025-06-26 08:11:24.996000
# Time to validate event C_na2d48ynn/BLACKLISTED/True/1750927360081: 17.37 seconds
# ℹ️ Label Event C_na2d48ynn/BLACKLISTED/True/1750927360081: Input label event resulted in NO_CHANGE to AH AH_rnm1rddys's active labels for BLACKLISTED. No events expected.
#
# Processing input event 2/10: C_hn2trayta/BLACKLISTED/True/1750947357545, effective_at=2025-06-26 14:15:57.545000
# Time to validate event C_0sd1a1msj/BLACKLISTED/True/1750945023575: 13.61 seconds
# ℹ️ Label Event C_0sd1a1msj/BLACKLISTED/True/1750945023575: Input label event resulted in NO_CHANGE to AH AH_j8m1x3d0s's active labels for BLACKLISTED. No events expected.
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 20.17 seconds
# - Fastest validation: 13.20 seconds
# - Slowest validation: 33.65 seconds
# - Total validation time for this batch: 201.71 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
# Validating 10 unique input label events.
# - C_g6cjdhmt3 -> BLACKLISTED=True @ 1750952218847
# - C_g029wqmnq -> BLACKLISTED=True @ 1750948078224
# - C_0cdwrgyyk -> BLACKLISTED=True @ 1750939421902
# - C_hx2n48yp2 -> HAS_CASH_CARD_DISPUTE=True @ 1750934118000
# - C_s92aq0mkq -> BLACKLISTED=True @ 1750943285794
# - C_sqencpy83 -> BLACKLISTED=True @ 1750947975023
# - C_syddxamj2 -> HAS_CASH_CHECK_RETURNS=True @ 1750929692776
# - C_gq2jw1mma -> BLACKLISTED=True @ 1750947156020
# - C_nydtjqy7f -> HAS_ANY_CASH_DISPUTE=True @ 1750948603000
# - C_gedeb1yb9 -> HAS_CASH_CARD_DISPUTE=True @ 1750934577000
#
# Processing input event 1/10: C_g6cjdhmt3/BLACKLISTED/True/1750952218847, effective_at=2025-06-26 15:36:58.847000
#
# Completed batch 5/100
# Time to validate event C_5ydnepmxr/BLACKLISTED/True/1750934578427: 27.15 seconds
# ℹ️ Label Event C_5ydnepmxr/BLACKLISTED/True/1750934578427: All validations passed
#
# Validation complete: 9/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 20.25 seconds
# - Fastest validation: 14.95 seconds
# - Slowest validation: 31.39 seconds
# - Total validation time for this batch: 202.49 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
# Validating 10 unique input label events.
# - C_sme7xpmrm -> HAS_ANY_CASH_DISPUTE=True @ 1750939963000
# - C_sqc0wqmyc -> BLACKLISTED=True @ 1750938209837
# - C_fteybgysa -> BLACKLISTED=True @ 1750952801034
# - C_8s2cehywm -> HAS_ANY_CASH_DISPUTE=True @ 1750949466000
# - C_0q2cpame5 -> HAS_CASH_CARD_DISPUTE=True @ 1750941124000
# - C_f0d6pqm9n -> BLACKLISTED=True @ 1750948182008
# - C_gje6camsg -> BLACKLISTED=True @ 1750951976649
# - C_sjegc0mk8 -> BLACKLISTED=True @ 1750936915350
# - C_gje1ehmez -> BLACKLISTED=True @ 1750932839843
# - C_g9dww1m6p -> BLACKLISTED=True @ 1750949402237
#
# Processing input event 1/10: C_sme7xpmrm/HAS_ANY_CASH_DISPUTE/True/1750939963000, effective_at=2025-06-26 12:12:43
#
# Completed batch 6/100
# Time to validate event C_hx2tj1y42/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750942568000: 24.04 seconds
# ℹ️ Label Event C_hx2tj1y42/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750942568000: All validations passed
#
# Validation complete: 9/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 20.33 seconds
# - Fastest validation: 12.74 seconds
# - Slowest validation: 33.68 seconds
# - Total validation time for this batch: 203.34 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
# Validating 10 unique input label events.
# - C_fxdcbpy9z -> HAS_CASH_CHECK_RETURNS=False @ 1750948982339
# - C_fadnqqy1r -> BLACKLISTED=True @ 1750933710081
# - C_0mdrxgm29 -> BLACKLISTED=True @ 1750944642244
# - C_50cbcpme0 -> BLACKLISTED=True @ 1750933634069
# - C_f4ewegy7g -> HAS_CASH_CARD_DISPUTE=True @ 1750942177000
# - C_0ydck1y2j -> HAS_CASH_CHECK_RETURNS=False @ 1750948989480
# - C_0xevw8mkh -> BLACKLISTED=True @ 1750933158311
# - C_hjeea8mk1 -> HAS_ANY_CASH_DISPUTE=True @ 1750952537000
# - C_80eww8y0s -> BLACKLISTED=True @ 1750938560349
# - C_gqe32am83 -> BLACKLISTED=True @ 1750953579041
#
# Completed batch 7/100
#
# Processing input event 1/10: C_fxdcbpy9z/HAS_CASH_CHECK_RETURNS/False/1750948982339, effective_at=2025-06-26 14:43:02.339000
# Time to validate event C_5jeg2amr8/BLACKLISTED/True/1750949466327: 20.24 seconds
# ℹ️ Label Event C_5jeg2amr8/BLACKLISTED/True/1750949466327: All validations passed
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 20.42 seconds
# - Fastest validation: 12.12 seconds
# - Slowest validation: 35.46 seconds
# - Total validation time for this batch: 204.16 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
# Validating 10 unique input label events.
# - C_8cwrkayr8 -> HAS_CASH_CARD_DISPUTE=True @ 1750948644000
# - C_0mckd8mm2 -> HAS_EV_SUSPENSION=False @ 1750946297858
# - C_n0dv2amxq -> BLACKLISTED=True @ 1750950897913
# - C_89eqp1mhx -> HAS_EV_SUSPENSION=False @ 1750940944901
# - C_nhec2qm0p -> HAS_ANY_CASH_DISPUTE=True @ 1750941460000
# - C_002vxamz7 -> BLACKLISTED=True @ 1750952861939
# - C_n0dbwgmmc -> BLACKLISTED=True @ 1750936033280
# - C_f9eb2qme8 -> BLACKLISTED=True @ 1750932165373
# - C_nqe2qamcz -> BLACKLISTED=True @ 1750927228048
# - C_s0ch9hy7p -> HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE=True @ 1750948245000
#
# Completed batch 8/100
#
# Processing input event 1/10: C_8cwrkayr8/HAS_CASH_CARD_DISPUTE/True/1750948644000, effective_at=2025-06-26 14:37:24
# Time to validate event C_5qc62amw1/BLACKLISTED/True/1750939027290: 28.91 seconds
# ℹ️ Label Event C_5qc62amw1/BLACKLISTED/True/1750939027290: All validations passed
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 20.82 seconds
# - Fastest validation: 13.46 seconds
# - Slowest validation: 36.52 seconds
# - Total validation time for this batch: 208.19 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
# Validating 10 unique input label events.
# - C_5nd5d1yg2 -> HAS_ANY_CASH_DISPUTE=True @ 1750944916000
# - C_sydnkhyfe -> BLACKLISTED=True @ 1750932271395
# - C_hmctdpym8 -> HAS_CASH_CARD_AFT_REASON_CODE_DISPUTE=True @ 1750938458000
# - C_0tdnqhmah -> HAS_ANY_CASH_DISPUTE=True @ 1750952985000
# - C_ht2wr0y51 -> BLACKLISTED=True @ 1750928655023
# - C_fjc12qmjm -> HAS_EV_SUSPENSION=True @ 1750931410712
# - C_nt2y98mk1 -> BLACKLISTED=True @ 1750947073358
# - C_hje7dqma8 -> BLACKLISTED=True @ 1750941667298
# - C_gndejqytc -> BLACKLISTED=True @ 1750945036230
# - C_502haam0q -> HAS_CASH_CHECK_RETURNS=False @ 1750948917759
#
# Processing input event 1/10: C_5nd5d1yg2/HAS_ANY_CASH_DISPUTE/True/1750944916000, effective_at=2025-06-26 13:35:16
#
# Completed batch 9/100
# Time to validate event C_80dka8mas/BLACKLISTED/True/1750936333813: 15.32 seconds
# ℹ️ Label Event C_80dka8mas/BLACKLISTED/True/1750936333813: Input label event resulted in NO_CHANGE to AH AH_sam8akd08's active labels for BLACKLISTED. No events expected.
#
# Processing input event 2/10: C_8xpkrgyvp/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750945100000, effective_at=2025-06-26 13:38:20
# Time to validate event C_hn2trayta/BLACKLISTED/True/1750947357545: 16.70 seconds
# ℹ️ Label Event C_hn2trayta/BLACKLISTED/True/1750947357545: Input label event resulted in NO_CHANGE to AH AH_demhazcm5's active labels for BLACKLISTED. No events expected.
#
# Processing input event 3/10: C_hmdbwhme6/BLACKLISTED/True/1750937937956, effective_at=2025-06-26 11:38:57.956000
# Time to validate event C_042zp0mb9/HAS_ANY_CASH_DISPUTE/True/1750945131000: 22.97 seconds
# ℹ️ Label Event C_042zp0mb9/HAS_ANY_CASH_DISPUTE/True/1750945131000: All validations passed
#
# Processing input event 2/10: C_h4cp4pmfh/BLACKLISTED/True/1750927655935, effective_at=2025-06-26 08:47:35.935000
# Time to validate event C_5xeep0yx6/BLACKLISTED/True/1750925484996: 22.14 seconds
# ℹ️ Label Event C_5xeep0yx6/BLACKLISTED/True/1750925484996: All validations passed
#
# Processing input event 2/10: C_8cevdpyvz/BLACKLISTED/True/1750948088773, effective_at=2025-06-26 14:28:08.773000
# Time to validate event C_fxdcbpy9z/HAS_CASH_CHECK_RETURNS/False/1750948982339: 15.57 seconds
# ℹ️ Label Event C_fxdcbpy9z/HAS_CASH_CHECK_RETURNS/False/1750948982339: Input label event resulted in NO_CHANGE to AH AH_z9ypbcdxf's active labels for HAS_CASH_CHECK_RETURNS. No events expected.
#
# Processing input event 2/10: C_fadnqqy1r/BLACKLISTED/True/1750933710081, effective_at=2025-06-26 10:28:30.081000
# Time to validate event C_sme7xpmrm/HAS_ANY_CASH_DISPUTE/True/1750939963000: 19.42 seconds
# ℹ️ Label Event C_sme7xpmrm/HAS_ANY_CASH_DISPUTE/True/1750939963000: All validations passed
#
# Processing input event 2/10: C_sqc0wqmyc/BLACKLISTED/True/1750938209837, effective_at=2025-06-26 11:43:29.837000
# Time to validate event C_g6cjdhmt3/BLACKLISTED/True/1750952218847: 20.41 seconds
# ℹ️ Label Event C_g6cjdhmt3/BLACKLISTED/True/1750952218847: All validations passed
#
# Processing input event 2/10: C_g029wqmnq/BLACKLISTED/True/1750948078224, effective_at=2025-06-26 14:27:58.224000
# Time to validate event C_8cwrkayr8/HAS_CASH_CARD_DISPUTE/True/1750948644000: 21.02 seconds
# ℹ️ Label Event C_8cwrkayr8/HAS_CASH_CARD_DISPUTE/True/1750948644000: All validations passed
#
# Processing input event 2/10: C_0mckd8mm2/HAS_EV_SUSPENSION/False/1750946297858, effective_at=2025-06-26 13:58:17.858000
# Time to validate event C_5nd5d1yg2/HAS_ANY_CASH_DISPUTE/True/1750944916000: 19.50 seconds
# ℹ️ Label Event C_5nd5d1yg2/HAS_ANY_CASH_DISPUTE/True/1750944916000: All validations passed
#
# Processing input event 2/10: C_sydnkhyfe/BLACKLISTED/True/1750932271395, effective_at=2025-06-26 10:04:31.395000
# Time to validate event C_8cevdpyvz/BLACKLISTED/True/1750948088773: 12.67 seconds
# ℹ️ Label Event C_8cevdpyvz/BLACKLISTED/True/1750948088773: Input label event resulted in NO_CHANGE to AH AH_zvypdvec8's active labels for BLACKLISTED. No events expected.
#
# Processing input event 3/10: C_gactc0yx9/HAS_EV_SUSPENSION/False/1750944943433, effective_at=2025-06-26 13:35:43.433000
# Time to validate event C_hmdbwhme6/BLACKLISTED/True/1750937937956: 18.11 seconds
# ℹ️ Label Event C_hmdbwhme6/BLACKLISTED/True/1750937937956: All validations passed
#
# Processing input event 4/10: C_5q2nxpme5/HAS_ANY_CASH_DISPUTE/True/1750946650000, effective_at=2025-06-26 14:04:10
# Time to validate event C_8xpkrgyvp/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750945100000: 20.68 seconds
# ℹ️ Label Event C_8xpkrgyvp/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750945100000: All validations passed
#
# Processing input event 3/10: C_fj2swamya/BLACKLISTED/True/1750937633678, effective_at=2025-06-26 11:33:53.678000
# Time to validate event C_g029wqmnq/BLACKLISTED/True/1750948078224: 13.18 seconds
# ℹ️ Label Event C_g029wqmnq/BLACKLISTED/True/1750948078224: Input label event resulted in NO_CHANGE to AH AH_qnmqw920g's active labels for BLACKLISTED. No events expected.
#
# Processing input event 3/10: C_0cdwrgyyk/BLACKLISTED/True/1750939421902, effective_at=2025-06-26 12:03:41.902000
# Time to validate event C_h4cp4pmfh/BLACKLISTED/True/1750927655935: 19.61 seconds
# ℹ️ Label Event C_h4cp4pmfh/BLACKLISTED/True/1750927655935: All validations passed
#
# Processing input event 3/10: C_nqdkxgm7n/BLACKLISTED/True/1750948831337, effective_at=2025-06-26 14:40:31.337000
# Time to validate event C_fadnqqy1r/BLACKLISTED/True/1750933710081: 20.00 seconds
# ℹ️ Label Event C_fadnqqy1r/BLACKLISTED/True/1750933710081: All validations passed
#
# Processing input event 3/10: C_0mdrxgm29/BLACKLISTED/True/1750944642244, effective_at=2025-06-26 13:30:42.244000
# Time to validate event C_sqc0wqmyc/BLACKLISTED/True/1750938209837: 20.17 seconds
# ℹ️ Label Event C_sqc0wqmyc/BLACKLISTED/True/1750938209837: All validations passed
#
# Processing input event 3/10: C_fteybgysa/BLACKLISTED/True/1750952801034, effective_at=2025-06-26 15:46:41.034000
# Time to validate event C_0mckd8mm2/HAS_EV_SUSPENSION/False/1750946297858: 19.33 seconds
# ℹ️ Label Event C_0mckd8mm2/HAS_EV_SUSPENSION/False/1750946297858: All validations passed
#
# Processing input event 3/10: C_n0dv2amxq/BLACKLISTED/True/1750950897913, effective_at=2025-06-26 15:14:57.913000
# Time to validate event C_gactc0yx9/HAS_EV_SUSPENSION/False/1750944943433: 15.16 seconds
# ℹ️ Label Event C_gactc0yx9/HAS_EV_SUSPENSION/False/1750944943433: Input label event resulted in NO_CHANGE to AH AH_9xy0ctcag's active labels for HAS_EV_SUSPENSION. No events expected.
#
# Processing input event 4/10: C_8ye2jhy33/BLACKLISTED/True/1750939781646, effective_at=2025-06-26 12:09:41.646000
# Time to validate event C_fj2swamya/BLACKLISTED/True/1750937633678: 15.41 seconds
# ℹ️ Label Event C_fj2swamya/BLACKLISTED/True/1750937633678: Input label event resulted in NO_CHANGE to AH AH_7qyhxz24f's active labels for BLACKLISTED. No events expected.
#
# Processing input event 4/10: C_sm24pqm8v/BLACKLISTED/True/1750930878291, effective_at=2025-06-26 09:41:18.291000
# Time to validate event C_sydnkhyfe/BLACKLISTED/True/1750932271395: 20.28 seconds
# ℹ️ Label Event C_sydnkhyfe/BLACKLISTED/True/1750932271395: All validations passed
#
# Processing input event 3/10: C_hmctdpym8/HAS_CASH_CARD_AFT_REASON_CODE_DISPUTE/True/1750938458000, effective_at=2025-06-26 11:47:38
# Time to validate event C_nqdkxgm7n/BLACKLISTED/True/1750948831337: 13.23 seconds
# ℹ️ Label Event C_nqdkxgm7n/BLACKLISTED/True/1750948831337: Input label event resulted in NO_CHANGE to AH AH_c8mg1ycs0's active labels for BLACKLISTED. No events expected.
#
# Processing input event 4/10: C_f42tpqmq3/BLACKLISTED/True/1750948326281, effective_at=2025-06-26 14:32:06.281000
# Time to validate event C_0mdrxgm29/BLACKLISTED/True/1750944642244: 14.01 seconds
# ℹ️ Label Event C_0mdrxgm29/BLACKLISTED/True/1750944642244: Input label event resulted in NO_CHANGE to AH AH_f8m0xf208's active labels for BLACKLISTED. No events expected.
#
# ...
#
# Processing input event 7/10: C_fmcgd0mfm/BLACKLISTED/True/1750952676476, effective_at=2025-06-26 15:44:36.476000
# Time to validate event C_862tx1yhq/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750925721000: 56.76 seconds
# ℹ️ Label Event C_862tx1yhq/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750925721000: All validations passed
#
# Processing input event 9/10: C_fme72am7h/BLACKLISTED/True/1750952676757, effective_at=2025-06-26 15:44:36.757000
# Time to validate event C_g9erehm3y/BLACKLISTED/True/1750949983767: 34.17 seconds
# ℹ️ Label Event C_g9erehm3y/BLACKLISTED/True/1750949983767: All validations passed
#
# Processing input event 4/10: C_s9cxx8y8f/BLACKLISTED/True/1750933861309, effective_at=2025-06-26 10:31:01.309000
# Time to validate event C_hcdzjgy6f/BLACKLISTED/True/1750950777898: 23.94 seconds
# ℹ️ Label Event C_hcdzjgy6f/BLACKLISTED/True/1750950777898: Input label event resulted in NO_CHANGE to AH AH_a5y1cdc98's active labels for BLACKLISTED. No events expected.
#
# Processing input event 8/10: C_s62ga1mz2/BLACKLISTED/True/1750951403302, effective_at=2025-06-26 15:23:23.302000
# Time to validate event C_fmcgd0mfm/BLACKLISTED/True/1750952676476: 17.35 seconds
# ℹ️ Label Event C_fmcgd0mfm/BLACKLISTED/True/1750952676476: Input label event resulted in NO_CHANGE to AH AH_mfm0dgcmf's active labels for BLACKLISTED. No events expected.
#
# Processing input event 8/10: C_8eey9qyx9/BLACKLISTED/True/1750934941264, effective_at=2025-06-26 10:49:01.264000
# Time to validate event C_njc22amy2/HAS_CASH_CARD_DISPUTE/True/1750941767000: 74.53 seconds
# ℹ️ Label Event C_njc22amy2/HAS_CASH_CARD_DISPUTE/True/1750941767000: All validations passed
#
# Processing input event 9/10: C_shwqk0yj9/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750940602000, effective_at=2025-06-26 12:23:22
# Time to validate event C_50c9camfz/BLACKLISTED/True/1750935780074: 38.07 seconds
# ℹ️ Label Event C_50c9camfz/BLACKLISTED/True/1750935780074: All validations passed
#
# Processing input event 4/10: C_g9dt90yc0/BLACKLISTED/True/1750945522438, effective_at=2025-06-26 13:45:22.438000
# Time to validate event C_fme72am7h/BLACKLISTED/True/1750952676757: 26.65 seconds
# ℹ️ Label Event C_fme72am7h/BLACKLISTED/True/1750952676757: Input label event resulted in NO_CHANGE to AH AH_m6mqemesg's active labels for BLACKLISTED. No events expected.
#
# Processing input event 10/10: C_njc9dhm22/BLACKLISTED/True/1750951995305, effective_at=2025-06-26 15:33:15.305000
# Time to validate event C_gcdtj0y6n/HAS_ANY_CASH_DISPUTE/True/1750940266000: 30.78 seconds
# ℹ️ Label Event C_gcdtj0y6n/HAS_ANY_CASH_DISPUTE/True/1750940266000: All validations passed
#
# Processing input event 6/10: C_0mcj2pms8/HAS_EV_SUSPENSION/True/1750948155546, effective_at=2025-06-26 14:29:15.546000
# Time to validate event C_s62ga1mz2/BLACKLISTED/True/1750951403302: 20.90 seconds
# ℹ️ Label Event C_s62ga1mz2/BLACKLISTED/True/1750951403302: Input label event resulted in NO_CHANGE to AH AH_2zm1ag26s's active labels for BLACKLISTED. No events expected.
#
# Processing input event 9/10: C_54c4c0mg8/BLACKLISTED/True/1750944534244, effective_at=2025-06-26 13:28:54.244000
# Time to validate event C_8eey9qyx9/BLACKLISTED/True/1750934941264: 21.10 seconds
# ℹ️ Label Event C_8eey9qyx9/BLACKLISTED/True/1750934941264: Input label event resulted in NO_CHANGE to AH AH_9xyq9yee8's active labels for BLACKLISTED. No events expected.
#
# Processing input event 9/10: C_842hx1m9v/HAS_CASH_CHECK_RETURNS/False/1750948941346, effective_at=2025-06-26 14:42:21.346000
# Time to validate event C_h4cnd0mab/HAS_CASH_CARD_DISPUTE/True/1750953363000: 41.19 seconds
# ℹ️ Label Event C_h4cnd0mab/HAS_CASH_CARD_DISPUTE/True/1750953363000: All validations passed
#
# Validation complete: 9/10 input label events passed.
#
# 1 label events failed due to code errors:
#   C_gje42am93/ACCOUNT_DENYLISTED/True/1750951763380: ValueError: Unsupported label event type for ID generation: NO CHANGE
#
# Timing statistics:
# - Average time per input label event: 39.43 seconds
# - Fastest validation: 21.30 seconds
# - Slowest validation: 110.34 seconds
# - Total validation time for this batch: 354.91 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
#
# Completed batch 92/100
# Time to validate event C_g9dt90yc0/BLACKLISTED/True/1750945522438: 23.62 seconds
# ℹ️ Label Event C_g9dt90yc0/BLACKLISTED/True/1750945522438: Input label event resulted in NO_CHANGE to AH AH_0cy09td9g's active labels for BLACKLISTED. No events expected.
#
# Processing input event 5/10: C_f62npqmwd/BLACKLISTED/True/1750933025167, effective_at=2025-06-26 10:17:05.167000
# Time to validate event C_842hx1m9v/HAS_CASH_CHECK_RETURNS/False/1750948941346: 19.03 seconds
# ℹ️ Label Event C_842hx1m9v/HAS_CASH_CHECK_RETURNS/False/1750948941346: Input label event resulted in NO_CHANGE to AH AH_v9m1xh248's active labels for HAS_CASH_CHECK_RETURNS. No events expected.
#
# Processing input event 10/10: C_ss2ba1m2d/BLACKLISTED/True/1750932777228, effective_at=2025-06-26 10:12:57.228000
# Time to validate event C_f62npqmwd/BLACKLISTED/True/1750933025167: 26.00 seconds
# ℹ️ Label Event C_f62npqmwd/BLACKLISTED/True/1750933025167: Input label event resulted in NO_CHANGE to AH AH_dwmqpn26f's active labels for BLACKLISTED. No events expected.
#
# Processing input event 6/10: C_h9d6wgm7w/BLACKLISTED/True/1750940671059, effective_at=2025-06-26 12:24:31.059000
# Time to validate event C_0mcj2pms8/HAS_EV_SUSPENSION/True/1750948155546: 41.96 seconds
# ℹ️ Label Event C_0mcj2pms8/HAS_EV_SUSPENSION/True/1750948155546: All validations passed
#
# Processing input event 7/10: C_nsd5p0mv6/HAS_CASH_CHECK_DUPLICATE_PRESENTMENT/True/1750929693000, effective_at=2025-06-26 09:21:33
# Time to validate event C_s9cxx8y8f/BLACKLISTED/True/1750933861309: 72.64 seconds
# ℹ️ Label Event C_s9cxx8y8f/BLACKLISTED/True/1750933861309: All validations passed
#
# Processing input event 5/10: C_0mcrapmzb/BLACKLISTED/True/1750950828636, effective_at=2025-06-26 15:13:48.636000
# Time to validate event C_njc9dhm22/BLACKLISTED/True/1750951995305: 52.09 seconds
# ℹ️ Label Event C_njc9dhm22/BLACKLISTED/True/1750951995305: All validations passed
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 37.31 seconds
# - Fastest validation: 21.35 seconds
# - Slowest validation: 56.76 seconds
# - Total validation time for this batch: 373.13 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
#
# Completed batch 93/100
# Time to validate event C_54c4c0mg8/BLACKLISTED/True/1750944534244: 45.26 seconds
# ℹ️ Label Event C_54c4c0mg8/BLACKLISTED/True/1750944534244: All validations passed
#
# Processing input event 10/10: C_fjekeqme3/BLACKLISTED/True/1750929222190, effective_at=2025-06-26 09:13:42.190000
# Time to validate event C_shwqk0yj9/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750940602000: 68.03 seconds
# ℹ️ Label Event C_shwqk0yj9/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750940602000: All validations passed
#
# Processing input event 10/10: C_fqe0dqmkg/BLACKLISTED/True/1750926397793, effective_at=2025-06-26 08:26:37.793000
# Time to validate event C_0mcrapmzb/BLACKLISTED/True/1750950828636: 16.37 seconds
# ℹ️ Label Event C_0mcrapmzb/BLACKLISTED/True/1750950828636: Input label event resulted in NO_CHANGE to AH AH_ammppkcs8's active labels for BLACKLISTED. No events expected.
#
# Processing input event 6/10: C_ss2aphyj1/BLACKLISTED/True/1750944386645, effective_at=2025-06-26 13:26:26.645000
# Time to validate event C_ss2ba1m2d/BLACKLISTED/True/1750932777228: 35.46 seconds
# ℹ️ Label Event C_ss2ba1m2d/BLACKLISTED/True/1750932777228: Input label event resulted in NO_CHANGE to AH AH_d2m1ab2ss's active labels for BLACKLISTED. No events expected.
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 28.79 seconds
# - Fastest validation: 17.35 seconds
# - Slowest validation: 48.94 seconds
# - Total validation time for this batch: 287.89 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
#
# Completed batch 94/100
# Time to validate event C_h9d6wgm7w/BLACKLISTED/True/1750940671059: 30.45 seconds
# ℹ️ Label Event C_h9d6wgm7w/BLACKLISTED/True/1750940671059: All validations passed
#
# Processing input event 7/10: C_89egdqm7g/BLACKLISTED/True/1750945213706, effective_at=2025-06-26 13:40:13.706000
# Time to validate event C_nsd5p0mv6/HAS_CASH_CHECK_DUPLICATE_PRESENTMENT/True/1750929693000: 31.72 seconds
# ℹ️ Label Event C_nsd5p0mv6/HAS_CASH_CHECK_DUPLICATE_PRESENTMENT/True/1750929693000: All validations passed
#
# Processing input event 8/10: C_gmdyeqyw9/HAS_CASH_CHECK_RETURNS/False/1750948961806, effective_at=2025-06-26 14:42:41.806000
# Time to validate event C_fjekeqme3/BLACKLISTED/True/1750929222190: 28.06 seconds
# ℹ️ Label Event C_fjekeqme3/BLACKLISTED/True/1750929222190: Source AH AH_3emqekejf has no connected target AHs. No events expected.
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 32.43 seconds
# - Fastest validation: 18.50 seconds
# - Slowest validation: 60.27 seconds
# - Total validation time for this batch: 324.31 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
#
# Completed batch 95/100
# Time to validate event C_gmdyeqyw9/HAS_CASH_CHECK_RETURNS/False/1750948961806: 18.85 seconds
# ℹ️ Label Event C_gmdyeqyw9/HAS_CASH_CHECK_RETURNS/False/1750948961806: Input label event resulted in NO_CHANGE to AH AH_9wyqeydmg's active labels for HAS_CASH_CHECK_RETURNS. No events expected.
#
# Processing input event 9/10: C_80dfx0msw/BLACKLISTED/True/1750935970421, effective_at=2025-06-26 11:06:10.421000
# Time to validate event C_fqe0dqmkg/BLACKLISTED/True/1750926397793: 36.47 seconds
# ℹ️ Label Event C_fqe0dqmkg/BLACKLISTED/True/1750926397793: All validations passed
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 47.98 seconds
# - Fastest validation: 25.81 seconds
# - Slowest validation: 74.53 seconds
# - Total validation time for this batch: 479.82 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
#
# Completed batch 96/100
# Time to validate event C_89egdqm7g/BLACKLISTED/True/1750945213706: 28.67 seconds
# ℹ️ Label Event C_89egdqm7g/BLACKLISTED/True/1750945213706: All validations passed
#
# Processing input event 8/10: C_fjd7wqmgn/BLACKLISTED/True/1750937758760, effective_at=2025-06-26 11:35:58.760000
# Time to validate event C_ss2aphyj1/BLACKLISTED/True/1750944386645: 40.89 seconds
# ℹ️ Label Event C_ss2aphyj1/BLACKLISTED/True/1750944386645: All validations passed
#
# Processing input event 7/10: C_nawfr1ys9/HAS_CASH_CHECK_RETURNS/False/1750949013439, effective_at=2025-06-26 14:43:33.439000
# Time to validate event C_80dfx0msw/BLACKLISTED/True/1750935970421: 15.60 seconds
# ℹ️ Label Event C_80dfx0msw/BLACKLISTED/True/1750935970421: Input label event resulted in NO_CHANGE to AH AH_55y0rwets's active labels for BLACKLISTED. No events expected.
#
# Processing input event 10/10: C_0qetw8yjf/HAS_ANY_CASH_DISPUTE/True/1750945389000, effective_at=2025-06-26 13:43:09
# Time to validate event C_fjd7wqmgn/BLACKLISTED/True/1750937758760: 15.81 seconds
# ℹ️ Label Event C_fjd7wqmgn/BLACKLISTED/True/1750937758760: Input label event resulted in NO_CHANGE to AH AH_btypkbwah's active labels for BLACKLISTED. No events expected.
#
# Processing input event 9/10: C_ns25r0meh/BLACKLISTED/True/1750930228615, effective_at=2025-06-26 09:30:28.615000
# Time to validate event C_nawfr1ys9/HAS_CASH_CHECK_RETURNS/False/1750949013439: 13.76 seconds
# ℹ️ Label Event C_nawfr1ys9/HAS_CASH_CHECK_RETURNS/False/1750949013439: Input label event resulted in NO_CHANGE to AH AH_9sy1rfwan's active labels for HAS_CASH_CHECK_RETURNS. No events expected.
#
# Processing input event 8/10: C_sscscam6a/BLACKLISTED/True/1750939009349, effective_at=2025-06-26 11:56:49.349000
# Time to validate event C_5sewx8m8j/BLACKLISTED/True/1750931427101: 211.27 seconds
# ❌ Label Event C_5sewx8m8j/BLACKLISTED/True/1750931427101: Validation failed
#
# Unexpected events (4):
#   - L/AH_hnm1ddeng/AH_j8m8xwes5/BLACKLISTED/1750931427101/+
#   - L/AH_vey11wdsf/AH_j8m8xwes5/BLACKLISTED/1750931427101/+
#   - L/AH_vtypqdd6g/AH_j8m8xwes5/BLACKLISTED/1750931427101/+
#   - L/AH_w6y1dveqs/AH_j8m8xwes5/BLACKLISTED/1750931427101/+
#
# Processing input event 10/10: C_50dexpys6/BLACKLISTED/True/1750948325895, effective_at=2025-06-26 14:32:05.895000
# Time to validate event C_ns25r0meh/BLACKLISTED/True/1750930228615: 18.30 seconds
# ℹ️ Label Event C_ns25r0meh/BLACKLISTED/True/1750930228615: Input label event resulted in NO_CHANGE to AH AH_hem0r52sn's active labels for BLACKLISTED. No events expected.
#
# Processing input event 10/10: C_n627p0mdw/BLACKLISTED/True/1750952709783, effective_at=2025-06-26 15:45:09.783000
# Time to validate event C_sscscam6a/BLACKLISTED/True/1750939009349: 19.69 seconds
# ℹ️ Label Event C_sscscam6a/BLACKLISTED/True/1750939009349: Input label event resulted in NO_CHANGE to AH AH_tdmgwke40's active labels for BLACKLISTED. No events expected.
#
# Processing input event 9/10: C_n0c2wpy9n/BLACKLISTED/True/1750933607991, effective_at=2025-06-26 10:26:47.991000
# Time to validate event C_n0c2wpy9n/BLACKLISTED/True/1750933607991: 19.32 seconds
# ℹ️ Label Event C_n0c2wpy9n/BLACKLISTED/True/1750933607991: Input label event resulted in NO_CHANGE to AH AH_n9ypw2c0n's active labels for BLACKLISTED. No events expected.
#
# Processing input event 10/10: C_5qdrxqmyb/BLACKLISTED/True/1750933669972, effective_at=2025-06-26 10:27:49.972000
# Time to validate event C_n627p0mdw/BLACKLISTED/True/1750952709783: 37.12 seconds
# ℹ️ Label Event C_n627p0mdw/BLACKLISTED/True/1750952709783: All validations passed
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 28.26 seconds
# - Fastest validation: 15.81 seconds
# - Slowest validation: 38.07 seconds
# - Total validation time for this batch: 282.56 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
#
# Completed batch 97/100
# Time to validate event C_5qdrxqmyb/BLACKLISTED/True/1750933669972: 24.60 seconds
# ℹ️ Label Event C_5qdrxqmyb/BLACKLISTED/True/1750933669972: Input label event resulted in NO_CHANGE to AH AH_bymqxrdq5's active labels for BLACKLISTED. No events expected.
#
# Validation complete: 10/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 32.31 seconds
# - Fastest validation: 13.76 seconds
# - Slowest validation: 72.64 seconds
# - Total validation time for this batch: 323.08 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
#
# Completed batch 98/100
# Time to validate event C_50dexpys6/BLACKLISTED/True/1750948325895: 60.61 seconds
# ℹ️ Label Event C_50dexpys6/BLACKLISTED/True/1750948325895: All validations passed
#
# Validation complete: 9/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 50.94 seconds
# - Fastest validation: 20.09 seconds
# - Slowest validation: 211.27 seconds
# - Total validation time for this batch: 509.37 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
#
# Completed batch 99/100
# Time to validate event C_0qetw8yjf/HAS_ANY_CASH_DISPUTE/True/1750945389000: 94.78 seconds
# ❌ Label Event C_0qetw8yjf/HAS_ANY_CASH_DISPUTE/True/1750945389000: Validation failed
#
# Unexpected events (1):
#   - L/AH_ffm0acca5/AH_fjy8wteq0/HAS_ANY_CASH_DISPUTE/1750945389000/+
#
# Validation complete: 9/10 input label events passed.
#
# Timing statistics:
# - Average time per input label event: 50.74 seconds
# - Fastest validation: 15.60 seconds
# - Slowest validation: 184.74 seconds
# - Total validation time for this batch: 507.41 seconds
#
# Results written to: bau_label_validation/bau_label_validation_20250701_021110.csv
#
# Completed batch 100/100
#
# All batches processed. Total time: 3815.77 seconds.
# Consolidated results are in: bau_label_validation/bau_label_validation_20250701_021110.csv

# %%
# Path to store validation outputs under. Create this beforehand with dbutils.fs.mkdirs(f"dbfs:/Users/...")
s3_dir = "Users/ioanna"

# Copy output to S3 for persistence
output_path = f"{s3_dir}/{output_file}"
dbutils.fs.cp(f"file://{os.getcwd()}/{output_file}", f"dbfs:/{output_path}")
# Out:
# Out[22]: True

# %%
# # Single label event validation
# result = validate_bau_label_event(
#     node_token="C_hqc22hyxf",
#     label_type="BLACKLISTED",
#     label_present=True,
#     effective_at_ms=1749545984851, 
#     ccgce_table=ccgce_table
# )
# print(result.get_summary())
# Out:
# ℹ️ Label Event C_hqc22hyxf/BLACKLISTED/True/1749545984851: All validations passed

# %% [markdown]
# ## Validation Result Analysis

# %%
# load file containing the validation results
validation_df = pd.read_csv(f"/dbfs/{output_path}")
validation_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label_event_id</th>
#       <th>validation_success</th>
#       <th>validation_status</th>
#       <th>missing_events</th>
#       <th>unexpected_events</th>
#       <th>timestamp_errors</th>
#       <th>connection_type_errors</th>
#       <th>payload_errors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>C_hj2bapmtt/BLACKLISTED/True/1750930520679</td>
#       <td>True</td>
#       <td>Input label event resulted in NO_CHANGE to AH ...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>C_hs2ja1mdc/BLACKLISTED/True/1750946181287</td>
#       <td>True</td>
#       <td>Input label event resulted in NO_CHANGE to AH ...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C_0nc5rhyf2/BLACKLISTED/True/1750938982725</td>
#       <td>True</td>
#       <td>All validations passed</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C_fy2t91yvf/HAS_ANY_CASH_DISPUTE/True/17509311...</td>
#       <td>True</td>
#       <td>All validations passed</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>C_09edphmsn/HAS_CASH_CHECK_RETURNS/True/175092...</td>
#       <td>True</td>
#       <td>All validations passed</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>988</th>
#       <td>C_n0c2wpy9n/BLACKLISTED/True/1750933607991</td>
#       <td>True</td>
#       <td>Input label event resulted in NO_CHANGE to AH ...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>989</th>
#       <td>C_n627p0mdw/BLACKLISTED/True/1750952709783</td>
#       <td>True</td>
#       <td>All validations passed</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>990</th>
#       <td>C_5qdrxqmyb/BLACKLISTED/True/1750933669972</td>
#       <td>True</td>
#       <td>Input label event resulted in NO_CHANGE to AH ...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>991</th>
#       <td>C_50dexpys6/BLACKLISTED/True/1750948325895</td>
#       <td>True</td>
#       <td>All validations passed</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>992</th>
#       <td>C_0qetw8yjf/HAS_ANY_CASH_DISPUTE/True/17509453...</td>
#       <td>False</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_ffm0acca5/AH_fjy8wteq0/HAS_ANY_CASH_DISPU...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <p>993 rows × 8 columns</p>
# </div>

# %%
# Failed validationss
failed_validations_df = validation_df[validation_df['validation_success'] == False][['label_event_id', 'validation_status', 'missing_events', 'unexpected_events', 'timestamp_errors', 'connection_type_errors']]
failed_validations_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label_event_id</th>
#       <th>validation_status</th>
#       <th>missing_events</th>
#       <th>unexpected_events</th>
#       <th>timestamp_errors</th>
#       <th>connection_type_errors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>C_n02waqm42/HAS_CASH_CARD_DID_NOT_MAKE_TRANSAC...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_00y1phcn5/AH_24mqaw20n/HAS_CASH_CARD_DID_...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>C_5nepxgmae/HAS_CASH_CARD_DISPUTE/True/1750941...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_19m1p5ets/AH_eamgxpen5/HAS_CASH_CARD_DISP...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>123</th>
#       <td>C_n0dv2amxq/BLACKLISTED/True/1750950897913</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_1fyg4ee4s/AH_qxma2vd0n/BLACKLISTED/175095...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>152</th>
#       <td>C_syddxamj2/HAS_CASH_CHECK_RETURNS/True/175092...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_7xm8cnets/AH_2jmaxddys/HAS_CASH_CHECK_RET...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>196</th>
#       <td>C_gedhwqmnp/HAS_CASH_CARD_DISPUTE/True/1750944...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_6hy0cpdtn/AH_pnmqwhdeg/HAS_CASH_CARD_DISP...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>229</th>
#       <td>C_nhec2qm0p/HAS_ANY_CASH_DISPUTE/True/17509414...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_1dyqehcaf/AH_p0mq2cehn/HAS_ANY_CASH_DISPU...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>239</th>
#       <td>C_nccnp1yte/HAS_CASH_CARD_DISPUTE/True/1750936...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_5gm0rydnh/AH_ety1pnccn/HAS_CASH_CARD_DISP...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>244</th>
#       <td>C_fqexdgm00/HAS_CASH_CARD_DISPUTE/True/1750949...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_mjy89td0s/AH_00mgdxeqf/HAS_CASH_CARD_DISP...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>275</th>
#       <td>C_5acvdqm99/HAS_CASH_CARD_DID_NOT_MAKE_TRANSAC...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_6cmqaf268/AH_99mqdvca5/HAS_CASH_CARD_DID_...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>286</th>
#       <td>C_sqc2rayrk/BLACKLISTED/True/1750941139530</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_vvygj8c68/AH_kryar2cqs/BLACKLISTED/175094...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>332</th>
#       <td>C_86c5dhy9e/HAS_CASH_CARD_DISPUTE/True/1750944...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_3amaq2can/AH_e9yhd5c68/HAS_CASH_CARD_DISP...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>341</th>
#       <td>C_5024wgmxs/BLACKLISTED/True/1750946312624</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Connection type mismatch for event L/AH_thmh4c...</td>
#     </tr>
#     <tr>
#       <th>408</th>
#       <td>C_fcd8dam9m/BLACKLISTED/True/1750942788505</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_fym1w82n5/AH_m9mad8dcf/BLACKLISTED/175094...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>424</th>
#       <td>C_5jdvw0mse/HAS_CASH_CARD_DISPUTE/True/1750951...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_p5m89nc4g/AH_esm0wvdj5/HAS_CASH_CARD_DISP...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>474</th>
#       <td>C_5acvdqm99/HAS_ANY_CASH_DISPUTE/True/17509470...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_azyapwdys/AH_99mqdvca5/HAS_ANY_CASH_DISPU...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>476</th>
#       <td>C_fmcck0ycx/BLACKLISTED/True/1750934193606</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_ffygaacx8/AH_xcy0kccmf/BLACKLISTED/175093...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>483</th>
#       <td>C_56cwjhmrd/BLACKLISTED/True/1750931219053</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_00ypwwcas/AH_drmhjwc65/BLACKLISTED/175093...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>487</th>
#       <td>C_fn2z9py25/HAS_CASH_CHECK_RETURNS/True/175092...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_spyhqx2an/AH_52yp9z2nf/HAS_CASH_CHECK_RET...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>526</th>
#       <td>C_hcp640yr4/HAS_ANY_CASH_DISPUTE/True/17509515...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_7xy12pd9g/AH_4ry046pch/HAS_ANY_CASH_DISPU...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>527</th>
#       <td>C_5he5rayjv/BLACKLISTED/True/1750929122046</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Connection type mismatch for event L/AH_sgmaar...</td>
#     </tr>
#     <tr>
#       <th>541</th>
#       <td>C_8q2xr8m3n/BLACKLISTED/True/1750939828148</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_esyabwcs0/AH_n3m8rx2q8/BLACKLISTED/175093...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>542</th>
#       <td>C_faw44gye3/HAS_CASH_CARD_CHARGED_WRONG_AMOUNT...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_d9ypp2e6n/AH_3eyg44waf/HAS_CASH_CARD_CHAR...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>577</th>
#       <td>C_gsd7aam48/BLACKLISTED/True/1750936613176</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Connection type mismatch for event L/AH_fny0rr...</td>
#     </tr>
#     <tr>
#       <th>614</th>
#       <td>C_002pq0md4/HAS_ANY_CASH_DISPUTE/True/17509459...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_2bya4nd0f/AH_4dm0qp200/HAS_ANY_CASH_DISPU...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>696</th>
#       <td>C_s92nagmkn/BLACKLISTED/True/1750925030465</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_27mqje20g/AH_nkmgan29s/BLACKLISTED/175092...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>708</th>
#       <td>C_hj2adpyk2/HAS_CASH_CARD_DISPUTE/True/1750940...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_4jm1r2eef/AH_2kypda2jh/HAS_CASH_CARD_DISP...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>765</th>
#       <td>C_st2xppm3m/BLACKLISTED/True/1750937188780</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_2kmgdc2xg/AH_m3mppx2ts/BLACKLISTED/175093...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>794</th>
#       <td>C_gnepaqy1r/BLACKLISTED/True/1750925139109</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_42m1p7d48/AH_r1yqapeng/BLACKLISTED/175092...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>817</th>
#       <td>C_5s2528mvc/HAS_CASH_CARD_DID_NOT_MAKE_TRANSAC...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_0mmp27cmn/AH_cvm8252s5/HAS_CASH_CARD_DID_...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>838</th>
#       <td>C_fjctr1yv8/BLACKLISTED/True/1750949037678</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Connection type mismatch for event L/AH_t2yp9t...</td>
#     </tr>
#     <tr>
#       <th>865</th>
#       <td>C_sjena1m23/HAS_ANY_CASH_DISPUTE/True/17509513...</td>
#       <td>FAIL</td>
#       <td>NaN</td>
#       <td>L/AH_r6m1x8ehf/AH_32m1anejs/HAS_ANY_CASH_D

# %%
if failed_validations_df.empty:
    print("All validations passed")
else:
    failed_validation_ids = failed_validations_df['label_event_id'].unique().tolist()
    num_failed = len(failed_validation_ids)
    all_validated = validation_df['label_event_id'].unique().tolist()
    num_validated = len(all_validated)
    print(f"{num_failed} out of {num_validated} label events had failed validations ({num_failed/num_validated*100:.2f}%):\n\n{failed_validation_ids}")
# Out:
# 35 out of 993 label events had failed validations (3.52%):
#
# ['C_n02waqm42/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750950093000', 'C_5nepxgmae/HAS_CASH_CARD_DISPUTE/True/1750941726000', 'C_n0dv2amxq/BLACKLISTED/True/1750950897913', 'C_syddxamj2/HAS_CASH_CHECK_RETURNS/True/1750929692776', 'C_gedhwqmnp/HAS_CASH_CARD_DISPUTE/True/1750944954000', 'C_nhec2qm0p/HAS_ANY_CASH_DISPUTE/True/1750941460000', 'C_nccnp1yte/HAS_CASH_CARD_DISPUTE/True/1750936537000', 'C_fqexdgm00/HAS_CASH_CARD_DISPUTE/True/1750949030000', 'C_5acvdqm99/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750947053000', 'C_sqc2rayrk/BLACKLISTED/True/1750941139530', 'C_86c5dhy9e/HAS_CASH_CARD_DISPUTE/True/1750944771000', 'C_5024wgmxs/BLACKLISTED/True/1750946312624', 'C_fcd8dam9m/BLACKLISTED/True/1750942788505', 'C_5jdvw0mse/HAS_CASH_CARD_DISPUTE/True/1750951461000', 'C_5acvdqm99/HAS_ANY_CASH_DISPUTE/True/1750947053000', 'C_fmcck0ycx/BLACKLISTED/True/1750934193606', 'C_56cwjhmrd/BLACKLISTED/True/1750931219053', 'C_fn2z9py25/HAS_CASH_CHECK_RETURNS/True/1750929695191', 'C_hcp640yr4/HAS_ANY_CASH_DISPUTE/True/1750951572000', 'C_5he5rayjv/BLACKLISTED/True/1750929122046', 'C_8q2xr8m3n/BLACKLISTED/True/1750939828148', 'C_faw44gye3/HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE/True/1750952288000', 'C_gsd7aam48/BLACKLISTED/True/1750936613176', 'C_002pq0md4/HAS_ANY_CASH_DISPUTE/True/1750945970000', 'C_s92nagmkn/BLACKLISTED/True/1750925030465', 'C_hj2adpyk2/HAS_CASH_CARD_DISPUTE/True/1750940534000', 'C_st2xppm3m/BLACKLISTED/True/1750937188780', 'C_gnepaqy1r/BLACKLISTED/True/1750925139109', 'C_5s2528mvc/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750952936000', 'C_fjctr1yv8/BLACKLISTED/True/1750949037678', 'C_sjena1m23/HAS_ANY_CASH_DISPUTE/True/1750951357000', 'C_fhecdamhk/BLACKLISTED/True/1750938827016', 'C_fqercqmg3/BLACKLISTED/True/1750952422166', 'C_5sewx8m8j/BLACKLISTED/True/1750931427101', 'C_0qetw8yjf/HAS_ANY_CASH_DISPUTE/True/1750945389000']

# %% [markdown]
# ### ✅ Missing events
#
# Account holders with expected events that were missing in the actual output.

# %%
# Filter rows where missing_events is not empty
missing_events_df = validation_df[validation_df['missing_events'].notna()]

if missing_events_df.empty:
    print("No missing events found in the validation results")
else:
    print(f"Found {len(missing_events_df)} label ids with missing events:\n{missing_events_df['label_event_id'].to_list()}\n")
    for _, row in missing_events_df.iterrows():
        events = row['missing_events'].split('|')
        print(f"Label event: {row['label_event_id']}")
        print(f"Number of missing events: {len(events)}")
        print("Missing events:")
        for event in events:
            print(f"  - {event}")
        print()
# Out:
# No missing events found in the validation results

# %% [markdown]
# ### ✅ Unexpected events
#
# Account holders who had actual events that were not expected based on the validation.
#
# A sample of the account holders that failed validation have been manually checked. In all cases the reason for the discrepancy was that the edge that caused the unexpected events exists in Duplograph's database (checked via RPC), but it's missing in `duplograph.public.edges` in Snowflake.

# %%
# Filter rows where unexpected_events is not empty
unexpected_events_df = validation_df[validation_df['unexpected_events'].notna()]

if unexpected_events_df.empty:
    print("No unexpected events found in the validation results")
else:
    print(f"Found {len(unexpected_events_df)} label ids with unexpected events: \n{unexpected_events_df['label_event_id'].to_list()}\n")
    
    for _, row in unexpected_events_df.iterrows():
        events = row['unexpected_events'].split('|')
        
        print(f"Label event: {row['label_event_id']}")
        print("Unexpected events:")
        for event in events:
            print(f"  - {event}")
        print()
# Out:
# Found 30 label ids with unexpected events:
# ['C_n02waqm42/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750950093000', 'C_5nepxgmae/HAS_CASH_CARD_DISPUTE/True/1750941726000', 'C_n0dv2amxq/BLACKLISTED/True/1750950897913', 'C_syddxamj2/HAS_CASH_CHECK_RETURNS/True/1750929692776', 'C_gedhwqmnp/HAS_CASH_CARD_DISPUTE/True/1750944954000', 'C_nhec2qm0p/HAS_ANY_CASH_DISPUTE/True/1750941460000', 'C_nccnp1yte/HAS_CASH_CARD_DISPUTE/True/1750936537000', 'C_fqexdgm00/HAS_CASH_CARD_DISPUTE/True/1750949030000', 'C_5acvdqm99/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750947053000', 'C_sqc2rayrk/BLACKLISTED/True/1750941139530', 'C_86c5dhy9e/HAS_CASH_CARD_DISPUTE/True/1750944771000', 'C_fcd8dam9m/BLACKLISTED/True/1750942788505', 'C_5jdvw0mse/HAS_CASH_CARD_DISPUTE/True/1750951461000', 'C_5acvdqm99/HAS_ANY_CASH_DISPUTE/True/1750947053000', 'C_fmcck0ycx/BLACKLISTED/True/1750934193606', 'C_56cwjhmrd/BLACKLISTED/True/1750931219053', 'C_fn2z9py25/HAS_CASH_CHECK_RETURNS/True/1750929695191', 'C_hcp640yr4/HAS_ANY_CASH_DISPUTE/True/1750951572000', 'C_8q2xr8m3n/BLACKLISTED/True/1750939828148', 'C_faw44gye3/HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE/True/1750952288000', 'C_002pq0md4/HAS_ANY_CASH_DISPUTE/True/1750945970000', 'C_s92nagmkn/BLACKLISTED/True/1750925030465', 'C_hj2adpyk2/HAS_CASH_CARD_DISPUTE/True/1750940534000', 'C_st2xppm3m/BLACKLISTED/True/1750937188780', 'C_gnepaqy1r/BLACKLISTED/True/1750925139109', 'C_5s2528mvc/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750952936000', 'C_sjena1m23/HAS_ANY_CASH_DISPUTE/True/1750951357000', 'C_fhecdamhk/BLACKLISTED/True/1750938827016', 'C_5sewx8m8j/BLACKLISTED/True/1750931427101', 'C_0qetw8yjf/HAS_ANY_CASH_DISPUTE/True/1750945389000']
#
# Label event: C_n02waqm42/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750950093000
# Unexpected events:
#   - L/AH_00y1phcn5/AH_24mqaw20n/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750950093000/+
#   - L/AH_9kyaahdqs/AH_24mqaw20n/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750950093000/+
#   - L/AH_m2ypw5d48/AH_24mqaw20n/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750950093000/+
#   - L/AH_ncmg9wex0/AH_24mqaw20n/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750950093000/+
#   - L/AH_pky0e2dn8/AH_24mqaw20n/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750950093000/+
#   - L/AH_zmy1edecs/AH_24mqaw20n/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750950093000/+
#
# Label event: C_5nepxgmae/HAS_CASH_CARD_DISPUTE/True/1750941726000
# Unexpected events:
#   - L/AH_19m1p5ets/AH_eamgxpen5/HAS_CASH_CARD_DISPUTE/1750941726000/+
#
# Label event: C_n0dv2amxq/BLACKLISTED/True/1750950897913
# Unexpected events:
#   - L/AH_1fyg4ee4s/AH_qxma2vd0n/BLACKLISTED/1750950897913/+
#   - L/AH_3xy0py2nh/AH_qxma2vd0n/BLACKLISTED/1750950897913/+
#   - L/AH_85yhjzcmf/AH_qxma2vd0n/BLACKLISTED/1750950897913/+
#   - L/AH_d0y0dv2ys/AH_qxma2vd0n/BLACKLISTED/1750950897913/+
#   - L/AH_fkmqcdey0/AH_qxma2vd0n/BLACKLISTED/1750950897913/+
#
# Label event: C_syddxamj2/HAS_CASH_CHECK_RETURNS/True/1750929692776
# Unexpected events:
#   - L/AH_7xm8cnets/AH_2jmaxddys/HAS_CASH_CHECK_RETURNS/1750929692776/+
#   - L/AH_zrmgrx2as/AH_2jmaxddys/HAS_CASH_CHECK_RETURNS/1750929692776/+
#
# Label event: C_gedhwqmnp/HAS_CASH_CARD_DISPUTE/True/1750944954000
# Unexpected events:
#   - L/AH_6hy0cpdtn/AH_pnmqwhdeg/HAS_CASH_CARD_DISPUTE/1750944954000/+
#   - L/AH_dtma2pcah/AH_pnmqwhdeg/HAS_CASH_CARD_DISPUTE/1750944954000/+
#   - L/AH_ppy1dtdeg/AH_pnmqwhdeg/HAS_CASH_CARD_DISPUTE/1750944954000/+
#   - L/AH_vtmaecetf/AH_pnmqwhdeg/HAS_CASH_CARD_DISPUTE/1750944954000/+
#
# Label event: C_nhec2qm0p/HAS_ANY_CASH_DISPUTE/True/1750941460000
# Unexpected events:
#   - L/AH_1dyqehcaf/AH_p0mq2cehn/HAS_ANY_CASH_DISPUTE/1750941460000/+
#   - L/AH_dmy0cdeng/AH_p0mq2cehn/HAS_ANY_CASH_DISPUTE/1750941460000/+
#   - L/AH_jyy0wyceg/AH_p0mq2cehn/HAS_ANY_CASH_DISPUTE/1750941460000/+
#   - L/AH_mhm1dw2nh/AH_p0mq2cehn/HAS_ANY_CASH_DISPUTE/1750941460000/+
#   - L/AH_peypxz2c5/AH_p0mq2cehn/HAS_ANY_CASH_DISPUTE/1750941460000/+
#   - L/AH_wyypwadaf/AH_p0mq2cehn/HAS_ANY_CASH_DISPUTE/1750941460000/+
#
# Label event: C_nccnp1yte/HAS_CASH_CARD_DISPUTE/True/1750936537000
# Unexpected events:
#   - L/AH_5gm0rydnh/AH_ety1pnccn/HAS_CASH_CARD_DISPUTE/1750936537000/+
#   - L/AH_e6m0bh2a5/AH_ety1pnccn/HAS_CASH_CARD_DISPUTE/1750936537000/+
#
# Label event: C_fqexdgm00/HAS_CASH_CARD_DISPUTE/True/1750949030000
# Unexpected events:
#   - L/AH_mjy89td0s/AH_00mgdxeqf/HAS_CASH_CARD_DISPUTE/1750949030000/+
#
# Label event: C_5acvdqm99/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750947053000
# Unexpected events:
#   - L/AH_6cmqaf268/AH_99mqdvca5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750947053000/+
#   - L/AH_azyapwdys/AH_99mqdvca5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750947053000/+
#   - L/AH_epm1w9e4s/AH_99mqdvca5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750947053000/+
#   - L/AH_qmy8btcch/AH_99mqdvca5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750947053000/+
#
# Label event: C_sqc2rayrk/BLACKLISTED/True/1750941139530
# Unexpected events:
#   - L/AH_vvygj8c68/AH_kryar2cqs/BLACKLISTED/1750941139530/+
#
# Label event: C_86c5dhy9e/HAS_CASH_CARD_DISPUTE/True/1750944771000
# Unexpected events:
#   - L/AH_3amaq2can/AH_e9yhd5c68/HAS_CASH_CARD_DISPUTE/1750944771000/+
#   - L/AH_7em0ax2n8/AH_e9yhd5c68/HAS_CASH_CARD_DISPUTE/1750944771000/+
#   - L/AH_cay0xpec0/AH_e9yhd5c68/HAS_CASH_CARD_DISPUTE/1750944771000/+
#   - L/AH_mpygeed4f/AH_e9yhd5c68/HAS_CASH_CARD_DISPUTE/1750944771000/+
#
# Label event: C_fcd8dam9m/BLACKLISTED/True/1750942788505
# Unexpected events:
#   - L/AH_fym1w82n5/AH_m9mad8dcf/BLACKLISTED/1750942788505/+
#
# Label event: C_5jdvw0mse/HAS_CASH_CARD_DISPUTE/True/1750951461000
# Unexpected events:
#   - L/AH_p5m89nc4g/AH_esm0wvdj5/HAS_CASH_CARD_DISPUTE/1750951461000/+
#
# Label event: C_5acvdqm99/HAS_ANY_CASH_DISPUTE/True/1750947053000
# Unexpected events:
#   - L/AH_azyapwdys/AH_99mqdvca5/HAS_ANY_CASH_DISPUTE/1750947053000/+
#   - L/AH_epm1w9e4s/AH_99mqdvca5/HAS_ANY_CASH_DISPUTE/1750947053000/+
#
# Label event: C_fmcck0ycx/BLACKLISTED/True/1750934193606
# Unexpected events:
#   - L/AH_ffygaacx8/AH_xcy0kccmf/BLACKLISTED/1750934193606/+
#
# Label event: C_56cwjhmrd/BLACKLISTED/True/1750931219053
# Unexpected events:
#   - L/AH_00ypwwcas/AH_drmhjwc65/BLACKLISTED/1750931219053/+
#   - L/AH_1by8phcxs/AH_drmhjwc65/BLACKLISTED/1750931219053/+
#   - L/AH_cgygx52t5/AH_drmhjwc65/BLACKLISTED/1750931219053/+
#   - L/AH_ghm8dhdn0/AH_drmhjwc65/BLACKLISTED/1750931219053/+
#   - L/AH_jzypb5290/AH_drmhjwc65/BLACKLISTED/1750931219053/+
#   - L/AH_vcm0cedcf/AH_drmhjwc65/BLACKLISTED/1750931219053/+
#   - L/AH_xyy8ph2hf/AH_drmhjwc65/BLACKLISTED/1750931219053/+
#
# Label event: C_fn2z9py25/HAS_CASH_CHECK_RETURNS/True/1750929695191
# Unexpected events:
#   - L/AH_spyhqx2an/AH_52yp9z2nf/HAS_CASH_CHECK_RETURNS/1750929695191/+
#
# Label event: C_hcp640yr4/HAS_ANY_CASH_DISPUTE/True/1750951572000
# Unexpected events:
#   - L/AH_7xy12pd9g/AH_4ry046pch/HAS_ANY_CASH_DISPUTE/1750951572000/+
#   - L/AH_eryg45295/AH_4ry046pch/HAS_ANY_CASH_DISPUTE/1750951572000/+
#   - L/AH_hnmpkwe45/AH_4ry046pch/HAS_ANY_CASH_DISPUTE/1750951572000/+
#
# Label event: C_8q2xr8m3n/BLACKLISTED/True/1750939828148
# Unexpected events:
#   - L/AH_esyabwcs0/AH_n3m8rx2q8/BLACKLISTED/1750939828148/+
#   - L/AH_h7y8wp2y8/AH_n3m8rx2q8/BLACKLISTED/1750939828148/+
#   - L/AH_n7mgr8295/AH_n3m8rx2q8/BLACKLISTED/1750939828148/+
#
# Label event: C_faw44gye3/HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE/True/1750952288000
# Unexpected events:
#   - L/AH_d9ypp2e6n/AH_3eyg44waf/HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE/1750952288000/+
#   - L/AH_fay02te60/AH_3eyg44waf/HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE/1750952288000/+
#   - L/AH_nxm115e4s/AH_3eyg44waf/HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE/1750952288000/+
#   - L/AH_psmqkdeys/AH_3eyg44waf/HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE/1750952288000/+
#   - L/AH_wpy8p8e6s/AH_3eyg44waf/HAS_CASH_CARD_CHARGED_WRONG_AMOUNT_DISPUTE/1750952288000/+
#
# Label event: C_002pq0md4/HAS_ANY_CASH_DISPUTE/True/1750945970000
# Unexpected events:
#   - L/AH_2bya4nd0f/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_6cy0peccf/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_8jmpxccng/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_9mypd5cjn/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_a4m8xeccf/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_acy84e2m8/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_aty8jn2m8/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_c9yp2v2s8/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_fby02ne95/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_fsyhdwe48/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_kxy0rpdm0/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_nkya2zcss/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_rkm0qacmn/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_sny0c52sg/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_x6m0bdcs0/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#   - L/AH_xhy122c4s/AH_4dm0qp200/HAS_ANY_CASH_DISPUTE/1750945970000/+
#
# Label event: C_s92nagmkn/BLACKLISTED/True/1750925030465
# Unexpected events:
#   - L/AH_27mqje20g/AH_nkmgan29s/BLACKLISTED/1750925030465/+
#   - L/AH_kqmpeeden/AH_nkmgan29s/BLACKLISTED/1750925030465/+
#   - L/AH_q0mqdacth/AH_nkmgan29s/BLACKLISTED/1750925030465/+
#   - L/AH_v6mqqxcxg/AH_nkmgan29s/BLACKLISTED/1750925030465/+
#
# Label event: C_hj2adpyk2/HAS_CASH_CARD_DISPUTE/True/1750940534000
# Unexpected events:
#   - L/AH_4jm1r2eef/AH_2kypda2jh/HAS_CASH_CARD_DISPUTE/1750940534000/+
#   - L/AH_eyypjpca8/AH_2kypda2jh/HAS_CASH_CARD_DISPUTE/1750940534000/+
#   - L/AH_f3ya42esh/AH_2kypda2jh/HAS_CASH_CARD_DISPUTE/1750940534000/+
#   - L/AH_phmgkz2eh/AH_2kypda2jh/HAS_CASH_CARD_DISPUTE/1750940534000/+
#   - L/AH_zhmqjnem8/AH_2kypda2jh/HAS_CASH_CARD_DISPUTE/1750940534000/+
#
# Label event: C_st2xppm3m/BLACKLISTED/True/1750937188780
# Unexpected events:
#   - L/AH_2kmgdc2xg/AH_m3mppx2ts/BLACKLISTED/1750937188780/+
#   - L/AH_fdm1cacnf/AH_m3mppx2ts/BLACKLISTED/1750937188780/+
#   - L/AH_p8mpaadag/AH_m3mppx2ts/BLACKLISTED/1750937188780/+
#   - L/AH_rbmgetcy8/AH_m3mppx2ts/BLACKLISTED/1750937188780/+
#
# Label event: C_gnepaqy1r/BLACKLISTED/True/1750925139109
# Unexpected events:
#   - L/AH_42m1p7d48/AH_r1yqapeng/BLACKLISTED/1750925139109/+
#   - L/AH_73ypcdcth/AH_r1yqapeng/BLACKLISTED/1750925139109/+
#   - L/AH_7zmgp02q5/AH_r1yqapeng/BLACKLISTED/1750925139109/+
#   - L/AH_bemhwq2q5/AH_r1yqapeng/BLACKLISTED/1750925139109/+
#   - L/AH_h0y1ep2n8/AH_r1yqapeng/BLACKLISTED/1750925139109/+
#   - L/AH_hzyqc8ees/AH_r1yqapeng/BLACKLISTED/1750925139109/+
#   - L/AH_krm8kz2x8/AH_r1yqapeng/BLACKLISTED/1750925139109/+
#   - L/AH_n6mpafdmh/AH_r1yqapeng/BLACKLISTED/1750925139109/+
#   - L/AH_ntmpwjdsg/AH_r1yqapeng/BLACKLISTED/1750925139109/+
#   - L/AH_saya4w2ch/AH_r1yqapeng/BLACKLISTED/1750925139109/+
#   - L/AH_tdm1a1d6g/AH_r1yqapeng/BLACKLISTED/1750925139109/+
#   - L/AH_wmmpa7eqn/AH_r1yqapeng/BLACKLISTED/1750925139109/+
#
# Label event: C_5s2528mvc/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/True/1750952936000
# Unexpected events:
#   - L/AH_0mmp27cmn/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_6dm8wg298/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_6mm1a92qf/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_6xmgas2qf/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_g1m0c9eqg/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_h0mp2kc08/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_h5mg2kc08/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_jrmaese0s/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_kfmq2qe9h/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_msm0c4emf/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_mzmaxje6h/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_qvm0cme95/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_szy8d22x5/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#   - L/AH_yamax6esf/AH_cvm8252s5/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750952936000/+
#
# Label event: C_sjena1m23/HAS_ANY_CASH_DISPUTE/True/1750951357000
# Unexpected events:
#   - L/AH_r6m1x8ehf/AH_32m1anejs/HAS_ANY_CASH_DISPUTE/1750951357000/+
#
# Label event: C_fhecdamhk/BLACKLISTED/True/1750938827016
# Unexpected events:
#   - L/AH_23mqa4dmf/AH_khmadcehf/BLACKLISTED/1750938827016/+
#   - L/AH_3nmpxfcmn/AH_khmadcehf/BLACKLISTED/1750938827016/+
#   - L/AH_3qypbwdcn/AH_khmadcehf/BLACKLISTED/1750938827016/+
#   - L/AH_5cmppre9s/AH_khmadcehf/BLACKLISTED/1750938827016/+
#   - L/AH_68y0jn2nf/AH_khmadcehf/BLACKLISTED/1750938827016/+
#   - L/AH_7cmp4vcnn/AH_khmadcehf/BLACKLISTED/1750938827016/+
#   - L/AH_87m8a4c0g/AH_khmadcehf/BLACKLISTED/1750938827016/+
#   - L/AH_c0mpa9ejg/AH_khmadcehf/BLACKLISTED/1750938827016/+
#   - L/AH_g0m8re2hs/AH_khmadcehf/BLACKLISTED/1750938827016/+
#   - L/AH_htmqafe05/AH_khmadcehf/BLACKLISTED/1750938827016/+
#   - L/AH_p1mpp3cjs/AH_khmadcehf/BLACKLISTED/1750938827016/+
#
# Label event: C_5sewx8m8j/BLACKLISTED/True/1750931427101
# Unexpected events:
#   - L/AH_hnm1ddeng/AH_j8m8xwes5/BLACKLISTED/1750931427101/+
#   - L/AH_vey11wdsf/AH_j8m8xwes5/BLACKLISTED/1750931427101/+
#   - L/AH_vtypqdd6g/AH_j8m8xwes5/BLACKLISTED/1750931427101/+
#   - L/AH_w6y1dveqs/AH_j8m8xwes5/BLACKLISTED/1750931427101/+
#
# Label event: C_0qetw8yjf/HAS_ANY_CASH_DISPUTE/True/1750945389000
# Unexpected events:
#   - L/AH_ffm0acca5/AH_fjy8wteq0/HAS_ANY_CASH_DISPUTE/1750945389000/+

# %% [markdown]
# ### ✅ Connection type mismatches
#
# Mismatches between expected and connection types on the change event between the source and target account holders.

# %%
# Filter rows where connection_type_errors is not empty
connection_type_errors_df = validation_df[validation_df['connection_type_errors'].notna()]

if connection_type_errors_df.empty:
    print("No label errors found in the validation results")
else:
    print(f"Found {len(connection_type_errors_df)} label ids with connection type errors:\n{connection_type_errors_df['label_event_id'].to_list()}\n")
    
    for _, row in connection_type_errors_df.iterrows():
        events = row['connection_type_errors'].split('|')
        
        print(f"Label event: {row['label_event_id']}")
        print("Connection type errors:")
        for event in events:
            print(f"  - {event}")
        print()
# Out:
# Found 5 label ids with connection type errors:
# ['C_5024wgmxs/BLACKLISTED/True/1750946312624', 'C_5he5rayjv/BLACKLISTED/True/1750929122046', 'C_gsd7aam48/BLACKLISTED/True/1750936613176', 'C_fjctr1yv8/BLACKLISTED/True/1750949037678', 'C_fqercqmg3/BLACKLISTED/True/1750952422166']
#
# Label event: C_5024wgmxs/BLACKLISTED/True/1750946312624
# Connection type errors:
#   - Connection type mismatch for event L/AH_thmh4cdxf/AH_sxmgw4205/BLACKLISTED/1750946312624/+:
#   Expected: ['SSN']
#   Actual:   ['SSN', 'VERIFIED_SSN']
#   - Connection type mismatch for event L/AH_rhmq4zdhn/AH_sxmgw4205/BLACKLISTED/1750946312624/+:
#   Expected: ['CASH_DEVICE', 'CASH_OPAQUE_APP_TOKEN', 'SSN']
#   Actual:   ['CASH_DEVICE', 'CASH_OPAQUE_APP_TOKEN', 'SSN', 'VERIFIED_SSN']
#   - Connection type mismatch for event L/AH_kym09x2h0/AH_sxmgw4205/BLACKLISTED/1750946312624/+:
#   Expected: ['SSN']
#   Actual:   ['SSN', 'VERIFIED_SSN']
#   - Connection type mismatch for event L/AH_82y1en2nh/AH_sxmgw4205/BLACKLISTED/1750946312624/+:
#   Expected: ['SSN']
#   Actual:   ['SSN', 'VERIFIED_SSN']
#   - Connection type mismatch for event L/AH_gny8d52jg/AH_sxmgw4205/BLACKLISTED/1750946312624/+:
#   Expected: ['SSN']
#   Actual:   ['SSN', 'VERIFIED_SSN']
#   - Connection type mismatch for event L/AH_vqy12hdm0/AH_sxmgw4205/BLACKLISTED/1750946312624/+:
#   Expected: ['SSN']
#   Actual:   ['SSN', 'VERIFIED_SSN']
#   - Connection type mismatch for event L/AH_c5m0w1e0h/AH_sxmgw4205/BLACKLISTED/1750946312624/+:
#   Expected: ['CASH_DEVICE', 'CASH_OPAQUE_APP_TOKEN', 'SSN']
#   Actual:   ['CASH_DEVICE', 'CASH_OPAQUE_APP_TOKEN', 'SSN', 'VERIFIED_SSN']
#   - Connection type mismatch for event L/AH_nwmpkdeh0/AH_sxmgw4205/BLACKLISTED/1750946312624/+:
#   Expected: ['CASH_DEVICE', 'CASH_OPAQUE_APP_TOKEN', 'SSN']
#   Actual:   ['CASH_DEVICE', 'CASH_OPAQUE_APP_TOKEN', 'SSN', 'VERIFIED_SSN']
#   - Connection type mismatch for event L/AH_tfya18dtg/AH_sxmgw4205/BLACKLISTED/1750946312624/+:
#   Expected: ['CASH_DEVICE', 'CASH_OPAQUE_APP_TOKEN', 'SSN']
#   Actual:   ['CASH_DEVICE', 'CASH_OPAQUE_APP_TOKEN', 'SSN', 'VERIFIED_SSN']
#
# Label event: C_5he5rayjv/BLACKLISTED/True/1750929122046
# Connection type errors:
#   - Connection type mismatch for event L/AH_sgmaar2mh/AH_vjyar5eh5/BLACKLISTED/1750929122046/+:
#   Expected: ['CASH_DEVICE', 'CASH_OPAQUE_APP_TOKEN', 'EMAIL', 'PHONE_NUMBER', 'VERIFIED_SSN']
#   Actual:   ['CASH_DEVICE', 'CASH_OPAQUE_APP_TOKEN', 'EMAIL', 'PHONE_NUMBER', 'SSN', 'VERIFIED_SSN']
#
# Label event: C_gsd7aam48/BLACKLISTED/True/1750936613176
# Connection type errors:
#   - Connection type mismatch for event L/AH_fny0rrwe8/AH_dayp2z2c5/BLACKLISTED/1750936613176/+:
#   Expected: ['CASH_BACKUP_TAG', 'CASH_DEVICE', 'SSN']
#   Actual:   ['CASH_BACKUP_TAG', 'SSN']
#
# Label event: C_fjctr1yv8/BLACKLISTED/True/1750949037678
# Connection type errors:
#   - Connection type mismatch for event L/AH_t2yp9tem5/AH_8vy1rtcjf/BLACKLISTED/1750949037678/+:
#   Expected: ['CASH_BACKUP_TAG', 'CASH_DEVICE', 'SSN']
#   Actual:   ['CASH_BACKUP_TAG', 'SSN']
#   - Connection type mismatch for event L/AH_k1y1kgpts/AH_8vy1rtcjf/BLACKLISTED/1750949037678/+:
#   Expected: ['CASH_BACKUP_TAG', 'CASH_DEVICE', 'SSN']
#   Actual:   ['CASH_BACKUP_TAG', 'SSN']
#
# Label event: C_fqercqmg3/BLACKLISTED/True/1750952422166
# Connection type errors:
#   - Connection type mismatch for event L/AH_9vy14jpcg/AH_3gmqcreqf/BLACKLISTED/1750952422166/+:
#   Expected: ['CASH_DEVICE', 'PAYMENT_CARD']
#   Actual:   ['PAYMENT_CARD']

# %% [markdown]
# ### ✅ Timestamp errors
#
# Account holders with mismatches between expected event timestamps (based on the effective_at of the label event that triggered the change event) and the actual `effective_at_millis` in the generated change events.

# %%
# Filter rows where timestamp_errors is not empty and not NaN
timestamp_errors_df = validation_df[
    validation_df['timestamp_errors'].notna() & (validation_df['timestamp_errors'] != '')
]

if timestamp_errors_df.empty:
    print("No timestamp errors found in the validation results.")
else:
    print(f"Found {len(timestamp_errors_df)} label ids with timestamp errors:\n{timestamp_errors_df['label_event_id'].to_list()}\n")
    for index, row in timestamp_errors_df.iterrows():
        label_id = row['label_event_id']
        # Split the pipe-separated error strings
        error_messages = row['timestamp_errors'].split('|')
        
        print(f"Label event: {label_id}")
        print(f"Number of timestamp errors: {len(error_messages)}")
        print("Timestamp error details:")
        for error_detail in error_messages:
            # Replace literal '\\n' from CSV with actual newlines for readable printing
            readable_error_detail = error_detail.replace('\\\\n', '\\n')
            print(f"  - {readable_error_detail}")
        print("\n") # Add a blank line for separation between labels
# Out:
# No timestamp errors found in the validation results.

# %% [markdown]
# ## ✅ General output checks
#
# Checks general properties of the output event data set:
# - Are there any events that have the same source_user_token and target_user_token?
# - Are there duplicate events with the same event_id? (if yes, checks whether their contents are also identical)
# - Are there are any events where event_time_millis is different to cash_connected_graph_change_event.effective_at_millis?
# - Are there any events where cash_connected_graph_change_event.label_change.changed_source_user_label is not in the event_id?
# - Are there any events where the source_user_token and target_user_token are not in the event_id?
# - Are there any events where the event_type does not match the event_id?
# - Are there any events where the effective_at does not match the event_id?

# %%
from pyspark.sql import DataFrame
from pyspark.sql.functions import udf, col, count as spark_count, lit, when
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql import functions as F

def parse_event_id(event_id: str) -> Tuple[str, str, str, str, str]:
    """Parse an event ID of format 'L/target/source/type/effective_at_ms/label_change' into its components.
    Returns (target, source, label_type, effective_at, label_change)."""
    try:
        _, remaining = event_id.split('L/', 1)
        target, source, label_type, effective_at, label_change = remaining.split('/')
        return (target, source, label_type, effective_at, label_change)
    except:
        return (None, None, None, None, None)
    
# Define the schema for the UDF's return type (a struct)
event_id_schema = StructType([
    StructField("id_target_token", StringType(), True),
    StructField("id_source_token", StringType(), True),
    StructField("id_label_type", StringType(), True),
    StructField("id_effective_at_millis_str", StringType(), True),
    StructField("id_marker", StringType(), True)
])

# Create the Spark UDF
parse_event_id_udf = udf(parse_event_id, event_id_schema)

def format_event(event: dict) -> str: 
    """Format a single CashConnectedGraphChangeEvent LabelChange event in a readable way."""
    # Convert connection_node_types to a sorted tuple for consistent display if it's a list
    conn_types_display = event.get('connection_node_types', [])
    if isinstance(conn_types_display, list):
        conn_types_display = tuple(sorted(conn_types_display))
    
    output = [
        f"Event ID: {event.get('event_id', 'N/A')}",
        f"Source: {event.get('source_user_token', 'N/A')}",
        f"Target: {event.get('target_user_token', 'N/A')}",
        f"Label Type: {event.get('changed_label_type', 'N/A')}",
        f"Effective At: {event.get('effective_at_millis', 'N/A')}",
        f"Published At: {event.get('published_at_millis', 'N/A')}",   
        f"Event Type: {event.get('event_type', 'N/A')}",
        f"Connection Node Types: {conn_types_display}",
        f"Event Time: {event.get('event_time_millis', 'N/A')}"
    ]
    return "\n  ".join(output)

def format_validation_sample(df: pd.DataFrame, validation_type: str, max_samples: int = 3) -> str:
    """Format validation results with samples of problematic events."""
    output = []
    for idx, event in df.head(max_samples).iterrows():
        output.append(f"\n{validation_type} {idx + 1}:")
        output.append("  " + format_event(event))
    return "\n".join(output)

# %%
def analyze_duplicate_event_ids(spark_df):
    """
    Analyze and report on duplicate event_ids in the Spark DataFrame.
    For each duplicated event_id, efficiently check at Spark scale
    that all business payload fields (with connection_node_types sorted) are identical.
    If mismatches are found, display a sample of actual differing payloads.
    """

    # List of business fields; for connection_node_types, use a sorted version
    business_fields = [
        'source_user_token',
        'target_user_token',
        'event_type',
        'changed_label_type',
        'effective_at_millis',
        'event_time_millis',
        'source_event_node_token',
        'source_event_label',
        'source_event_present',
        'source_event_effective_at',
        'source_event_created_at',
        'source_event_updated_at'
        # 'connection_node_types' will be replaced by the sorted version below
    ]

    print("\n\n2. Event IDs that appear more than once:")

    unique_event_ids_count = spark_df.select("event_id").distinct().count()
    print(f"  Total unique event_ids: {unique_event_ids_count}")

    # Add a sorted version of connection_node_types for canonical comparison
    spark_df_sorted = spark_df.withColumn(
        "conn_types_sorted",
        F.sort_array(F.col("connection_node_types"))
    )

    # Create a struct for business fields including the sorted connection_node_types
    spark_df_struct = spark_df_sorted.withColumn(
        "business_payload",
        F.struct(*([F.col(c) for c in business_fields] + [F.col("conn_types_sorted")]))
    )

    # Group and count duplicates and distinct business payloads per event_id
    dupe_payload_check = (
        spark_df_struct.groupBy("event_id")
        .agg(
            F.count("*").alias("dup_count"),
            F.countDistinct("business_payload").alias("distinct_payload_count")
        )
        .filter(F.col("dup_count") > 1)
        .cache()
    )

    total_dupe_event_ids = dupe_payload_check.count()
    print(f"  Total duplicate event_ids checked: {total_dupe_event_ids}")

    # Find event_ids where payloads are not all identical
    bad_dupes = dupe_payload_check.filter("distinct_payload_count > 1").cache()
    num_bad_dupes = bad_dupes.count()
    print(f"  Number of duplicate event_ids with NON-identical business payloads: {num_bad_dupes}")

    if num_bad_dupes > 0:
        print("\nSample of non-identical duplicates (event_id, dup_count, distinct_payload_count):")
        bad_dupes.select("event_id", "dup_count", "distinct_payload_count").show(10, truncate=False)
        
        # Show actual mismatched payloads for up to 3 problematic event_ids
        bad_ids = [row.event_id for row in bad_dupes.limit(5).collect()]
        if bad_ids:
            print("\nSample mismatched payloads for problematic event_ids:")
            mismatches = spark_df_struct.filter(F.col("event_id").isin(bad_ids)).select(
                "event_id", *business_fields, "conn_types_sorted", "published_at_millis", "source_label_event"
            ).orderBy("event_id", "event_time_millis", "published_at_millis")
            mismatches.show(50, truncate=False)
    else:
        print("All duplicate event_ids are identical in the specified business fields (with connection_node_types compared as sets).")

    # Optionally: show top 10 most common duplicates (by count)
    print("\n  Top 10 event_ids with most duplicates:")
    dupe_payload_check.orderBy(F.col("dup_count").desc()).select("event_id", "dup_count").show(10, truncate=False)

    # Cleanup
    dupe_payload_check.unpersist()
    bad_dupes.unpersist()
    return total_dupe_event_ids, num_bad_dupes

# %%
def validate_bau_label_output(ccgce_table: str, spark_session):
    """Validate general properties of BAU label events using Spark for performance.
    
    Args:
        ccgce_table: Full name of the CashConnectedGraphChangeEvent table to validate.
        spark_session: The active SparkSession.
    """
    query = f"""
    SELECT 
        event_time_millis,
        cash_connected_graph_change_event.event_id as event_id,
        cash_connected_graph_change_event.source_user_token as source_user_token,
        cash_connected_graph_change_event.target_user_token as target_user_token,
        cash_connected_graph_change_event.effective_at_millis as effective_at_millis,
        cash_connected_graph_change_event.published_at_millis as published_at_millis,
        cash_connected_graph_change_event.event_type as event_type,
        cash_connected_graph_change_event.label_change.changed_source_user_label as changed_label_type,
        cash_connected_graph_change_event.label_change.connection_node_types as connection_node_types,
        cash_connected_graph_change_event.label_change.source_label_event.node.token as source_event_node_token,
        cash_connected_graph_change_event.label_change.source_label_event.label as source_event_label,
        cash_connected_graph_change_event.label_change.source_label_event.effective_at_msec as source_event_effective_at,
        cash_connected_graph_change_event.label_change.source_label_event.present as source_event_present,
        cash_connected_graph_change_event.label_change.source_label_event.created_at as source_event_created_at,
        cash_connected_graph_change_event.label_change.source_label_event.updated_at as source_event_updated_at
    FROM {ccgce_table}
    WHERE cash_connected_graph_change_event.event_source_type = 'BAU'
    AND cash_connected_graph_change_event.label_change IS NOT NULL
    """
    
    spark_df = spark_session.sql(query)
    spark_df.cache() 
    
    total_events = spark_df.count()
    print(f"Total BAU LabelChange events to validate: {total_events}\n")
    if total_events == 0:
        spark_df.unpersist()
        return

    spark_df_parsed = spark_df.withColumn("id_parts", parse_event_id_udf(col("event_id")))
    spark_df_parsed.cache() # Cache the parsed version as well

    # 1. Events with same source and target user
    self_ref_df_spark = spark_df_parsed.filter(col("source_user_token") == col("target_user_token"))
    self_ref_count = self_ref_df_spark.count()
    print("\n1. Events with same source and target user:")
    print(f"Total count: {self_ref_count}")
    if self_ref_count > 0:
        print("\nSample of such events:")
        print(format_validation_sample(self_ref_df_spark.limit(3).toPandas(), "Self-referential event"))

    # 2. Analyze Duplicate Event IDs
    dup_id_count, dup_mismatched_payload_count = analyze_duplicate_event_ids(spark_df_parsed)

    # 3. Events with event_time_millis != effective_at_millis
    timestamp_mismatch_df_spark = spark_df_parsed.filter(col("event_time_millis") != col("effective_at_millis"))
    timestamp_mismatch_count = timestamp_mismatch_df_spark.count()
    print("\n\n3. Events with event_time_millis != effective_at_millis:")
    print(f"Total count: {timestamp_mismatch_count}")
    if timestamp_mismatch_count > 0:
        print("\nSample of such events:")
        print(format_validation_sample(timestamp_mismatch_df_spark.limit(3).toPandas(), "Mismatched root timestamp"))

    # 4. Events where label_change.changed_source_user_label (payload) is not in the event_id
    label_type_mismatch_df_spark = spark_df_parsed.filter(col("id_parts.id_label_type") != col("changed_label_type"))
    label_type_mismatch_count = label_type_mismatch_df_spark.count()
    print("\n\n4. Events where changed_label_type (payload) != id_label_type (from event_id):") 
    print(f"Total count: {label_type_mismatch_count}")
    if label_type_mismatch_count > 0:
        print("\nSample of such events:") 
        print(format_validation_sample(label_type_mismatch_df_spark.limit(3).toPandas(), "Label type mismatch (payload vs ID)"))

    # 5. Events where source/target user tokens (payload) are not in the event_id (in specific order: target then source in ID)
    token_mismatch_df_spark = spark_df_parsed.filter(
        (col("id_parts.id_target_token") != col("target_user_token")) | \
        (col("id_parts.id_source_token") != col("source_user_token"))
    )
    token_mismatch_count = token_mismatch_df_spark.count()
    print("\n\n5. Events where source/target tokens (payload) don't match event_id structure:") 
    print(f"Total count: {token_mismatch_count}")
    if token_mismatch_count > 0:
        print("\nSample of such events:") 
        print(format_validation_sample(token_mismatch_df_spark.limit(3).toPandas(), "Token mismatch (payload vs ID)"))

    # 6. Events where event_type (payload) does not match the marker in event_id
    event_type_vs_marker_mismatch_df_spark = spark_df_parsed.withColumn(
        "expected_marker",
        when(col("event_type") == lit("LABEL_ADDED"), lit("+"))
        .when(col("event_type") == lit("LABEL_REMOVED"), lit("-"))
        .otherwise(lit("UNKNOWN_MARKER_FOR_EVENT_TYPE"))
    ).filter(col("id_parts.id_marker") != col("expected_marker"))
    event_type_vs_marker_mismatch_count = event_type_vs_marker_mismatch_df_spark.count()
    print("\n\n6. Events where event_type (payload) marker doesn't match id_marker (from event_id):") 
    print(f"Total count: {event_type_vs_marker_mismatch_count}")
    if event_type_vs_marker_mismatch_count > 0:
        print("\nSample of such events:") 
        print(format_validation_sample(event_type_vs_marker_mismatch_df_spark.limit(3).toPandas(), "EventType/Marker mismatch"))
        
    # 7. Events where effective_at_millis (payload) does not match effective_at_ms in event_id
    effective_at_mismatch_df_spark = spark_df_parsed.filter(
        col("id_parts.id_effective_at_millis_str") != col("effective_at_millis").cast(StringType())
    )
    effective_at_mismatch_count = effective_at_mismatch_df_spark.count()
    print("\n\n7. Events where effective_at_millis (payload) doesn't match id_effective_at_millis_str (from event_id):") 
    print(f"Total count: {effective_at_mismatch_count}")
    if effective_at_mismatch_count > 0:
        print("\nSample of such events:")
        print(format_validation_sample(effective_at_mismatch_df_spark.limit(3).toPandas(), "EffectiveAt mismatch (payload vs ID)"))

    # --- Summary ---
    print("\n\n--- Overall Sanity Check Summary ---") 
    print(f"Total events validated: {total_events}")
    print(f"1. Self-referential events: {self_ref_count}")
    print(f"2. Event IDs with duplicates: {dup_id_count}. With mismarched payloads: {dup_mismatched_payload_count}")
    print(f"3. Root timestamp mismatches (event_time_millis vs effective_at_millis): {timestamp_mismatch_count}")
    print(f"4. Payload label_type vs. Event ID label_type mismatches: {label_type_mismatch_count}")
    print(f"5. Payload tokens vs. Event ID tokens mismatches: {token_mismatch_count}")
    print(f"6. Payload event_type vs. Event ID marker mismatches: {event_type_vs_marker_mismatch_count}")
    print(f"7. Payload effective_at vs. Event ID effective_at mismatches: {effective_at_mismatch_count}")

    spark_df_parsed.unpersist() # Unpersist the parsed df
    spark_df.unpersist()

# %%
validate_bau_label_output(ccgce_table, spark)
# Out:
# Total BAU LabelChange events to validate: 6743088
#
#
# 1. Events with same source and target user:
# Total count: 0
#
#
# 2. Event IDs that appear more than once:
#   Total unique event_ids: 4152611
#   Total duplicate event_ids checked: 1892141
#   Number of duplicate event_ids with NON-identical business payloads: 0
# All duplicate event_ids are identical in the specified business fields (with connection_node_types compared as sets).
#
#   Top 10 event_ids with most duplicates:
# +------------------------------------------------------------------------------------------+---------+
# |event_id                                                                                  |dup_count|
# +------------------------------------------------------------------------------------------+---------+
# |L/AH_e3ypkswng/AH_ksy04x2x0/HAS_CASH_CARD_AFT_REASON_CODE_DISPUTE/1750976222000/+         |4        |
# |L/AH_cfmgjpcag/AH_8hma4neyf/HAS_CASH_CARD_AFT_REASON_CODE_DISPUTE/1750974064000/+         |4        |
# |L/AH_shmhkh2qh/AH_n8mgx3e00/HAS_CASH_CARD_AFT_REASON_CODE_DISPUTE/1750924303000/+         |4        |
# |L/AH_bsm0pm24g/AH_zkyqrtets/HAS_CASH_CARD_AFT_REASON_CODE_DISPUTE/1750899198000/+         |4        |
# |L/AH_60m1rw20n/AH_b4y8kmpn8/HAS_CASH_CARD_DID_NOT_MAKE_TRANSACTION_DISPUTE/1750953828000/+|4        |
# |L/AH_7fyqjndhn/AH_zkyqrtets/HAS_ANY_CASH_DISPUTE/1750899198000/+                          |4        |
# |L/AH_6hmhkacns/AH_z7mprwces/HAS_CASH_CARD_DISPUTE/1750925555000/+                         |4        |
# |L/AH_vsyh4tdys/AH_zkyqrtets/HAS_ANY_CASH_DISPUTE/1750899198000/+                          |4        |
# |L/AH_7rm0ed2hh/AH_ksy04x2x0/HAS_CASH_CARD_AFT_REASON_CODE_DISPUTE/1750976222000/+         |4        |
# |L/AH_1fyaj22af/AH_z7mprwces/HAS_ANY_CASH_DISPUTE/1750925555000/+                          |4        |
# +------------------------------------------------------------------------------------------+---------+
# only showing top 10 rows
#
#
#
# 3. Events with event_time_millis != effective_at_millis:
# Total count: 0
#
#
# 4. Events where changed_label_type (payload) != id_label_type (from event_id):
# Total count: 0
#
#
# 5. Events where source/target tokens (payload) don't match event_id structure:
# Total count: 0
#
#
# 6. Events where event_type (payload) marker doesn't match id_marker (from event_id):
# Total count: 0
#
#
# 7. Events where effective_at_millis (payload) doesn't match id_effective_at_millis_str (from event_id):
# Total count: 0
#
#
# --- Overall Sanity Check Summary ---
# Total events validated: 6743088
# 1. Self-referential events: 0
# 2. Event IDs with duplicates: 1892141. With mismarched payloads: 0
# 3. Root timestamp mismatches (event_time_millis vs effective_at_millis): 0
# 4. Payload label_type vs. Event ID label_type mismatches: 0
# 5. Payload tokens vs. Event ID tokens mismatches: 0
# 6. Payload event_type vs. Event ID marker mismatches: 0
# 7. Payload effective_at vs. Event ID effective_at mismatches: 0

# %% [markdown]
# ### Duplicate event_ids in output
#
# A large number of duplicate `event_id`s were observed in edgy's LabelChange output events. Further analysis confirmed that for all such duplicates the contents of the events are identical except for `published_at_millis`.
#
# Presidio log analysis showed that that duplicate consumption of label events happens consistently not just in edgy's `LabelKafkaSAMConsumer`, but also in other downstream consumers of Duplograph label events (such as Duplograph's signals service), confirming that the duplication originates upstream.
#
# Downstream consumers of these events (i.e. Beacon and Foundry) handle KnowledgeEvents with identical `event_id` and `event_time_millis` as duplicates, so the presence of these duplicate events in edgy's output should not result in incorrect downstream processing. Therefore no action is required as far as signal correctness goes, but the duplicate processing IS adding unnecessary load to the system so it would be good to address it upstream in Duplograph.
